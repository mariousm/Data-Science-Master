# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">M2.883 · Aprendizaje por refuerzo</p>
# <p style="margin: 0; text-align:right;">Máster universitario en Ciencia de datos (<i>Data science</i>)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Estudios de Informática, Multimedia y Telecomunicación</p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>
#
#
# # PEC2: Deep Reinforcement Learning
#
#
# En esta práctica se implementarán tres modelos de DRL en un mismo entorno, con el objetivo de analizar distintas formas de aprendizaje de un agente y estudiar su rendimiento. El agente será entrenado con los métodos:
#
# <ol>
#     <li>DQN</li>
#     <li>Double DQN (DDQN)</li>
#     <li>REINFORCE con línea de base</li>
#     <li>REINFORCE con reward modificado </li>
#  </ol>
#
# Finalmente, crearemos un entorno de cero y lo resolveremos.
#
#
# **Importante: La entrega debe hacerse en formato notebook y en formato html donde se vea el código y los resultados y comentarios de cada ejercicio. Para exportar el notebook a html puede hacerse desde el menú File  →  Download as  →  HTML.**

# %% [markdown]
# # Autor: Mario Ubierna San Mamés

# %% [markdown]
# ## 0. Contexto

# %% [markdown]
# **Mountain Car** consiste en un coche situado en un valle. El coche tiene muy poca potencia y sólo con su motor no es capaz de salir del valle porque la gravedad es más fuerte. Para ello, el agente debe conseguir impulsar el coche, ya sea acelerando hacia adelante o hacia atrás a la velocidad más adecuada para poder  llegar a la cima de la montaña y salir del valle.

# %% [markdown]
# Las acciones que puede realizar el coche son las siguientes:
# <ul>
#     <li>0 : Acelerar hacia a la izquierda</li>
#     <li>1 : No usar el motor</li>
#     <li>2 : Acelerar hacia la derecha</li>
# </ul>

# %% [markdown]
# ![title](mountainCar.jpg)

# %% [markdown]
# El agente recibirá una recompensa (penalización) de -1 cada vez que no consiga llegar a la posición objetivo.
#
# Para más detalles sobre la definición del entorno de MountainCar, se recomienda consultar el código fuente: https://github.com/openai/gym/blob/master/gym/envs/classic_control/mountain_car.py

# %% [markdown]
# Cada episodio termina cuando el coche ha llegado al punto objetivo o si se han realizado 200 pasos. La solución óptima es aquella en la que el agente, con un desplazamiento eficiente, consigue llegar a la cima en el menor número de pasos posible.

# %% [markdown]
# <!-- Sure, in the second solution, I modified the reward function so that the agent received a reward based on its position. If the agent failed an episode by not getting to the top of the hill but got further to the right from the previous episode it still learns that going right is better even though it ultimately failed the task. Without this reinforcement, the agent has to reach the top of the hill by random chance before receiving a reward signal that causes it to modify its behavior in future episodes. -->

# %% [markdown]
# ## 1. Inicialización y exploración del entorno (0.5 ptos)

# %% [markdown]
# Empezaremos cargando las principales librerías necesarias para la práctica:

# %%
import gym
import matplotlib.pyplot as plt
# %matplotlib inline
import torch
import numpy as np
import time

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.1 ptos):</strong> Inicializar el entorno 'MountainCar-v0'. Extraer:
#
#    <ul>
#         <li>Valor del umbral de recompensa definido en el entorno</li>
#         <li>Máximo de pasos establecidos por cada episodio</li>
#         <li>Dimensión del espacio de acciones</li>
#         <li>Espacio de estados</li>
#         <li>Dimensión del espacio de estados</li>
#         <li>Valores mínimos permitidos de posición y velocidad</li>
#        <li>Valores máximos permitidos de posición y velocidad</li>
# </ul>
# </div>

# %%
env = gym.make('MountainCar-v0')

# %%
print("El máximo número de pasos por episodio es: {}".format(env.spec.max_episode_steps))
print("La dimensión del espacio de acciones es: {}".format(env.action_space.n))
print("El espacio de estados es: {}".format(env.observation_space))
print("La dimensión del espacio de estados: {}".format(env.observation_space.shape[0]))
print("La dimensión del espacio de estados: {}".format(env.observation_space.shape))
print("La dimensión del espacio de estados: {}".format(env.observation_space.sample()))
# Out:
# El máximo número de pasos por episodio es: 200
# La dimensión del espacio de acciones es: 3
# El espacio de estados es: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# La dimensión del espacio de estados: 2
# La dimensión del espacio de estados: (2,)
# La dimensión del espacio de estados: [-0.748207   -0.02993124]

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.2 ptos):</strong> Mostrar la representación vectorial de cada observación del entorno junto con la acción aleatoria seleccionada (ej. 'Observation: [..] , Action: Accelerate left'), en un intervalo de 10 episodios de 100 pasos cada uno.
#
# <i>Opcional</i>: visualizar los 10 episodios <code>env.render()</code>, sólo posible en local
# </div>

# %%
def translate_action(action):
    actions_space = {
        0: "Accelerate left",
        1: "No accelerating",
        2: "Accelerate right"
    }
    return actions_space[action]

# %%
num_episodios = 10
num_pasos = 100

for episodio in range(num_episodios):
    obs = env.reset()
    print("***********")
    print("Episode: " + str(episodio + 1))
    print("***********")
    
    for paso in range(num_pasos):
        linea = ""
        # Añadimos la observación
        linea += str(obs)
        # Añadimos la acción
        accion = env.action_space.sample()
        linea += " -> " + translate_action(accion)
        
        new_obs, reward, done, info = env.step(accion)
        obs = new_obs
        print(linea)
        if done:
            print(str(obs) + " -> End")
            break
# Out:
# ***********
# Episode: 1
# ***********
# [-0.50276  0.     ] -> Accelerate right
# [-0.5019162   0.00084381] -> No accelerating
# [-0.5012349   0.00068131] -> No accelerating
# [-0.5007212  0.0005137] -> No accelerating
# [-5.0037897e-01  3.4225619e-04] -> Accelerate left
# [-0.5012107  -0.00083175] -> Accelerate right
# [-5.0121021e-01  4.6389567e-07] -> Accelerate left
# [-0.50237757 -0.00116732] -> Accelerate right
# [-5.027039e-01 -3.263756e-04] -> No accelerating
# [-5.0318694e-01 -4.8298432e-04] -> Accelerate left
# [-0.5048229  -0.00163598] -> No accelerating
# [-0.5065996  -0.00177672] -> No accelerating
# [-0.5085038  -0.00190416] -> Accelerate left
# [-0.5115211  -0.00301733] -> Accelerate right
# [-0.513629  -0.0021079] -> Accelerate left
# [-0.51681167 -0.00318266] -> No accelerating
# [-0.5200452  -0.00323356] -> Accelerate right
# [-0.5223054  -0.00226021] -> No accelerating
# [-0.52457535 -0.00226991] -> Accelerate left
# [-0.52783793 -0.00326259] -> Accelerate right
# [-0.53006876 -0.00223079] -> Accelerate left
# [-0.533251   -0.00318227] -> Accelerate right
# [-0.5353609  -0.00210989] -> No accelerating
# [-0.5373826  -0.00202169] -> Accelerate left
# [-0.5403009  -0.00291834] -> No accelerating
# [-0.54309404 -0.00279313] -> No accelerating
# [-0.5457411 -0.002647 ] -> Accelerate left
# [-0.5492221  -0.00348105] -> Accelerate left
# [-0.5535112  -0.00428907] -> Accelerate left
# [-0.5585762  -0.00506503] -> Accelerate left
# [-0.5643794  -0.00580318] -> Accelerate right
# [-0.56887746 -0.00449808] -> Accelerate left
# [-0.574037   -0.00515954] -> No accelerating
# [-0.5788197  -0.00478269] -> Accelerate right
# [-0.5821901  -0.00337043] -> Accelerate right
# [-0.5841234  -0.00193325] -> Accelerate right
# [-5.8460516e-01 -4.8180748e-04] -> No accelerating
# [-5.8463198e-01 -2.6809546e-05] -> Accelerate right
# [-0.5832036   0.00142839] -> Accelerate right
# [-0.58033055  0.00287304] -> No accelerating
# [-0.57703406  0.00329648] -> No accelerating
# [-0.57333857  0.00369553] -> Accelerate right
# [-0.56827134  0.0050672 ] -> Accelerate left
# [-0.56387013  0.00440124] -> Accelerate right
# [-0.5581676   0.00570254] -> No accelerating
# [-0.5522062   0.00596134] -> Accelerate right
# [-0.5450306   0.00717563] -> Accelerate left
# [-0.5386943   0.00633626] -> No accelerating
# [-0.53224486  0.00644944] -> Accelerate left
# [-0.5267306   0.00551428] -> No accelerating
# [-0.52119285  0.00553777] -> Accelerate left
# [-0.51667315  0.00451972] -> Accelerate right
# [-0.5112053   0.00546778] -> Accelerate right
# [-0.5048305   0.00637485] -> Accelerate left
# [-0.49959633  0.00523417] -> No accelerating
# [-0.494542   0.0050543] -> Accelerate right
# [-0.48870537  0.00583665] -> Accelerate left
# [-0.48412994  0.00457543] -> Accelerate left
# [-0.48084983  0.00328011] -> Accelerate left
# [-0.47888947  0.00196037] -> Accelerate right
# [-0.4762634   0.00262605] -> Accelerate right
# [-0.47299117  0.00327223] -> No accelerating
# [-0.47009706  0.00289413] -> No accelerating
# [-0.46760246  0.00249459] -> Accelerate left
# [-0.46652588  0.00107659] -> No accelerating
# [-0.46587524  0.00065063] -> Accelerate left
# [-0.4666554  -0.00078014] -> Accelerate left
# [-0.46886054 -0.00220514] -> Accelerate left
# [-0.47247437 -0.00361383] -> No accelerating
# [-0.47647014 -0.00399577] -> Accelerate left
# [-0.4818182  -0.00534805] -> Accelerate left
# [-0.48847878 -0.00666059] -> Accelerate left
# [-0.49640226 -0.0079235 ] -> Accelerate left
# [-0.5055295  -0.00912725] -> Accelerate left
# [-0.51579225 -0.0102627 ] -> Accelerate right
# [-0.52511346 -0.00932125] -> Accelerate left
# [-0.53542334 -0.01030989] -> Accelerate right
# [-0.5446446  -0.00922122] -> Accelerate right
# [-0.5527081  -0.00806348] -> Accelerate left
# [-0.5615535  -0.00884544] -> Accelerate left
# [-0.5711149  -0.00956139] -> No accelerating
# [-0.58032113 -0.00920623] -> Accelerate left
# [-0.590104   -0.00978286] -> Accelerate right
# [-0.59839135 -0.00828737] -> Accelerate left
# [-0.6071225  -0.00873112] -> Accelerate right
# [-0.61423373 -0.00711123] -> No accelerating
# [-0.62067354 -0.00643981] -> Accelerate right
# [-0.62539554 -0.004722  ] -> No accelerating
# [-0.62936586 -0.00397034] -> No accelerating
# [-0.6325562  -0.00319033] -> No accelerating
# [-0.63494384 -0.00238762] -> Accelerate left
# [-0.6375118  -0.00256798] -> Accelerate right
# [-0.63824195 -0.00073016] -> No accelerating
# [-6.3812917e-01  1.1280945e-04] -> No accelerating
# [-0.6371742   0.00095499] -> Accelerate left
# [-0.6363838   0.00079041] -> No accelerating
# [-0.6347635   0.00162025] -> Accelerate right
# [-0.6313249   0.00343862] -> No accelerating
# [-0.6270923   0.00423258] -> No accelerating
# [-0.62209594  0.00499637] -> Accelerate left
# ***********
# Episode: 2
# ***********
# [-0.4405395  0.       ] -> No accelerating
# [-0.44115603 -0.00061652] -> Accelerate left
# [-0.4433846  -0.00222855] -> Accelerate left
# [-0.44720894 -0.00382437] -> Accelerate right
# [-0.45060125 -0.00339229] -> No accelerating
# [-0.45453665 -0.00393541] -> No accelerating
# [-0.45898634 -0.00444968] -> Accelerate left
# [-0.46491757 -0.00593124] -> Accelerate right
# [-0.47028664 -0.00536908] -> Accelerate left
# [-0.47705388 -0.00676722] -> No accelerating
# [-0.48416904 -0.00711517] -> No accelerating
# [-0.49157923 -0.00741021] -> Accelerate right
# [-0.49822924 -0.00664998] -> No accelerating
# [-0.5050693  -0.00684007] -> No accelerating
# [-0.5120483  -0.00697897] -> Accelerate right
# [-0.51811385 -0.00606558] -> Accelerate left
# [-0.5252206  -0.00710672] -> Accelerate right
# [-0.53131515 -0.00609455] -> Accelerate right
# [-0.5363518  -0.00503669] -> No accelerating
# [-0.5412929  -0.00494106] -> No accelerating
# [-0.5461013  -0.00480842] -> No accelerating
# [-0.5507411  -0.00463978] -> Accelerate right
# [-0.5541775  -0.00343644] -> Accelerate left
# [-0.55838495 -0.00420742] -> Accelerate right
# [-0.5613319  -0.00294699] -> Accelerate right
# [-0.5629965 -0.0016646] -> Accelerate right
# [-5.6336635e-01 -3.6980366e-04] -> Accelerate right
# [-0.5624386   0.00092775] -> No accelerating
# [-0.56122017  0.00121839] -> Accelerate right
# [-0.55872023  0.00249995] -> Accelerate right
# [-0.5549574   0.00376287] -> Accelerate left
# [-0.55195963  0.00299771] -> Accelerate right
# [-0.5477495   0.00421016] -> Accelerate left
# [-0.5443584   0.00339114] -> No accelerating
# [-0.5408116   0.00354673] -> Accelerate right
# [-0.53613585  0.00467577] -> No accelerating
# [-0.53136605  0.00476978] -> Accelerate right
# [-0.525538    0.00582803] -> Accelerate left
# [-0.5206955   0.00484257] -> Accelerate left
# [-0.5168747  0.0038208] -> No accelerating
# [-0.5131043   0.00377037] -> No accelerating
# [-0.50941265  0.00369167] -> Accelerate left
# [-0.50682735  0.00258531] -> No accelerating
# [-0.50436777  0.00245958] -> No accelerating
# [-0.5020523   0.00231543] -> Accelerate left
# [-0.50089836  0.00115394] -> Accelerate left
# [-5.0091457e-01 -1.6182152e-05] -> Accelerate left
# [-0.50210077 -0.00118618] -> No accelerating
# [-0.50344807 -0.00134731] -> No accelerating
# [-0.5049464  -0.00149834] -> Accelerate right
# [-0.50558454 -0.00063816] -> No accelerating
# [-0.5063578 -0.0007732] -> No accelerating
# [-0.5072602  -0.00090245] -> Accelerate right
# [-5.0728518e-01 -2.4944906e-05] -> Accelerate right
# [-0.5064324   0.00085275] -> Accelerate left
# [-5.0670838e-01 -2.7593892e-04] -> Accelerate left
# [-0.50811094 -0.00140256] -> No accelerating
# [-0.5096296  -0.00151868] -> Accelerate right
# [-0.510253   -0.00062342] -> Accelerate left
# [-0.5119765  -0.00172348] -> Accelerate right
# [-0.51278716 -0.00081063] -> No accelerating
# [-0.51367885 -0.00089171] -> Accelerate right
# [-5.1364493e-01  3.3904344e-05] -> No accelerating
# [-5.136857e-01 -4.073835e-05] -> Accelerate right
# [-0.51280075  0.00088492] -> No accelerating
# [-0.5119968   0.00080395] -> Accelerate right
# [-0.51027983  0.00171696] -> No accelerating
# [-0.50866276  0.00161709] -> Accelerate left
# [-5.081577e-01  5.051080e-04] -> Accelerate right
# [-0.5067683   0.00138934] -> Accelerate right
# [-0.50450516  0.00226317] -> Accelerate right
# [-0.5013851   0.00312004] -> Accelerate right
# [-0.49743155  0.00395356] -> Accelerate right
# [-0.49267402  0.00475751] -> No accelerating
# [-0.48814812  0.00452591] -> Accelerate left
# [-0.4848876   0.00326053] -> Accelerate right
# [-0.48091674  0.00397085] -> No accelerating
# [-0.47726515  0.0036516 ] -> No accelerating
# [-0.47395992  0.00330522] -> Accelerate right
# [-0.4700256  0.0039343] -> Accelerate right
# [-0.46549138  0.00453423] -> No accelerating
# [-0.46139076  0.00410063] -> Accelerate left
# [-0.45875397  0.00263677] -> Accelerate right
# [-0.45560047  0.0031535 ] -> Accelerate left
# [-0.45395344  0.00164704] -> Accelerate right
# [-0.45182493  0.00212849] -> Accelerate left
# [-0.4512306   0.00059434] -> Accelerate right
# [-0.45017478  0.00105583] -> Accelerate right
# [-0.44866517  0.0015096 ] -> No accelerating
# [-0.44771287  0.00095231] -> No accelerating
# [-4.4732478e-01  3.8807388e-04] -> Accelerate right
# [-0.4465038  0.000821 ] -> No accelerating
# [-4.4625586e-01  2.4792677e-04] -> Accelerate left
# [-0.4475828  -0.00132695] -> No accelerating
# [-0.44947496 -0.00189215] -> Accelerate right
# [-0.45091847 -0.0014435 ] -> No accelerating
# [-0.45290276 -0.0019843 ] -> Accelerate right
# [-0.4544133  -0.00151055] -> Accelerate right
# [-0.45543903 -0.00102572] -> Accelerate right
# [-0.4559724  -0.00053337] -> Accelerate right
# ***********
# Episode: 3
# ***********
# [-0.5565978  0.       ] -> Accelerate left
# [-0.5573507  -0.00075291] -> Accelerate left
# [-0.55885094 -0.0015002 ] -> No accelerating
# [-0.5600872  -0.00123631] -> Accelerate left
# [-0.5620504  -0.00196319] -> Accelerate right
# [-0.56272584 -0.00067544] -> Accelerate right
# [-0.5621085   0.00061734] -> No accelerating
# [-0.561203    0.00090552] -> No accelerating
# [-0.56001604  0.00118695] -> No accelerating
# [-0.5585565   0.00145954] -> Accelerate right
# [-0.55583525  0.00272124] -> Accelerate left
# [-0.55387264  0.00196264] -> No accelerating
# [-0.55168325  0.00218938] -> Accelerate right
# [-0.54828346  0.00339977] -> Accelerate right
# [-0.5436987   0.00458473] -> No accelerating
# [-0.5389633   0.00473539] -> Accelerate right
# [-0.53311276  0.00585058] -> No accelerating
# [-0.5271908   0.00592193] -> Accelerate right
# [-0.520242    0.00694887] -> Accelerate left
# [-0.5143183   0.00592369] -> Accelerate left
# [-0.50946414  0.0048541 ] -> Accelerate right
# [-0.50371605  0.00574812] -> No accelerating
# [-0.49811697  0.00559909] -> No accelerating
# [-0.4927088   0.00540816] -> Accelerate right
# [-0.48653197  0.00617682] -> Accelerate left
# [-0.4816326   0.00489939] -> Accelerate right
# [-0.47604713  0.00558547] -> Accelerate right
# [-0.46981707  0.00623005] -> Accelerate right
# [-0.46298864  0.00682843] -> Accelerate left
# [-0.45761228  0.00537635] -> Accelerate right
# [-0.4517276   0.00588468] -> Accelerate left
# [-0.4473778   0.00434982] -> Accelerate right
# [-0.44259465  0.00478313] -> No accelerating
# [-0.4384131   0.00418156] -> Accelerate right
# [-0.4338635  0.0045496] -> No accelerating
# [-0.42997882  0.00388468] -> Accelerate left
# [-0.4277871   0.00219173] -> Accelerate left
# [-0.4273041   0.00048299] -> Accelerate left
# [-0.42853332 -0.00122921] -> Accelerate right
# [-0.4294659  -0.00093258] -> Accelerate left
# [-0.4320951  -0.00262923] -> Accelerate left
# [-0.43640205 -0.00430692] -> No accelerating
# [-0.4413555  -0.00495346] -> Accelerate right
# [-0.44591954 -0.00456405] -> No accelerating
# [-0.45106092 -0.00514138] -> Accelerate left
# [-0.45774207 -0.00668113] -> No accelerating
# [-0.4649139  -0.00717185] -> Accelerate right
# [-0.47152364 -0.00660972] -> No accelerating
# [-0.47852233 -0.00699869] -> Accelerate left
# [-0.48685807 -0.00833574] -> Accelerate left
# [-0.49646878 -0.00961073] -> No accelerating
# [-0.5062828  -0.00981399] -> Accelerate right
# [-0.5152266 -0.0089438] -> No accelerating
# [-0.52423316 -0.00900658] -> Accelerate right
# [-0.53223497 -0.00800182] -> No accelerating
# [-0.54017204 -0.00793706] -> No accelerating
# [-0.54798484 -0.00781281] -> Accelerate left
# [-0.55661494 -0.00863008] -> No accelerating
# [-0.5649978  -0.00838286] -> No accelerating
# [-0.57307094 -0.00807317] -> Accelerate left
# [-0.5817745  -0.00870349] -> Accelerate left
# [-0.59104383 -0.00926938] -> Accelerate left
# [-0.6008108  -0.00976699] -> Accelerate right
# [-0.6090039  -0.00819306] -> No accelerating
# [-0.6165634  -0.00755951] -> No accelerating
# [-0.62343466 -0.00687128] -> No accelerating
# [-0.62956834 -0.00613365] -> No accelerating
# [-0.63492054 -0.0053522 ] -> Accelerate right
# [-0.63845325 -0.00353272] -> Accelerate right
# [-0.6401415  -0.00168826] -> No accelerating
# [-0.6409734  -0.00083189] -> Accelerate right
# [-0.63994306  0.00103034] -> No accelerating
# [-0.6380577   0.00188532] -> Accelerate left
# [-0.6363307   0.00172699] -> Accelerate right
# [-0.6327743   0.00355645] -> No accelerating
# [-0.62841356  0.00436071] -> Accelerate right
# [-0.62227964  0.00613393] -> No accelerating
# [-0.61541635  0.00686327] -> No accelerating
# [-0.60787314  0.00754323] -> Accelerate left
# [-0.60070455  0.00716857] -> No accelerating
# [-0.59296286  0.00774172] -> No accelerating
# [-0.58470464  0.00825821] -> Accelerate right
# [-0.5749907   0.00971394] -> No accelerating
# [-0.5648928   0.01009785] -> Accelerate right
# [-0.5534861   0.01140677] -> Accelerate left
# [-0.54285544  0.01063062] -> Accelerate right
# [-0.5310805   0.01177497] -> Accelerate left
# [-0.5202494   0.01083108] -> Accelerate right
# [-0.5084435   0.01180596] -> No accelerating
# [-0.49675113  0.01169233] -> Accelerate left
# [-0.48625994  0.01049119] -> No accelerating
# [-0.4760482   0.01021173] -> Accelerate right
# [-0.4651919   0.01085631] -> Accelerate right
# [-0.45377138  0.0114205 ] -> No accelerating
# [-0.44287077  0.01090062] -> No accelerating
# [-0.4325697   0.01030106] -> Accelerate right
# [-0.42194292  0.01062679] -> Accelerate right
# [-0.4110668   0.01087614] -> Accelerate left
# [-0.4020187   0.00904809] -> Accelerate left
# [-0.39486238  0.00715632] -> Accelerate right
# ***********
# Episode: 4
# ***********
# [-0.58791053  0.        ] -> No accelerating
# [-5.8743119e-01  4.7935132e-04] -> Accelerate left
# [-5.874760e-01 -4.482628e-05] -> Accelerate left
# [-5.8804470e-01 -5.6867383e-04] -> Accelerate left
# [-0.589133   -0.00108834] -> Accelerate left
# [-0.590733   -0.00159999] -> Accelerate left
# [-0.59283286 -0.00209988] -> Accelerate left
# [-0.59541726 -0.00258435] -> No accelerating
# [-0.5974671  -0.00204987] -> Accelerate left
# [-0.5999675  -0.00250038] -> No accelerating
# [-0.6019001  -0.00193261] -> Accelerate left
# [-0.60425085 -0.00235074] -> Accelerate right
# [-0.6050026  -0.00075173] -> Accelerate left
# [-0.6061498  -0.00114725] -> Accelerate right
# [-6.056842e-01  4.655699e-04] -> Accelerate right
# [-0.60360926  0.00207501] -> Accelerate right
# [-0.5999399   0.00366934] -> No accelerating
# [-0.595703    0.00423691] -> Accelerate left
# [-0.5919295   0.00377348] -> Accelerate left
# [-0.5886471   0.00328238] -> Accelerate right
# [-0.58387995  0.00476715] -> Accelerate right
# [-0.5776632  0.0062168] -> Accelerate left
# [-0.57204264  0.00562051] -> Accelerate left
# [-0.5670601   0.00498256] -> Accelerate right
# [-0.5607525  0.0063076] -> No accelerating
# [-0.55416685  0.00658567] -> No accelerating
# [-0.54735225  0.00681461] -> Accelerate left
# [-0.5413596   0.00599261] -> Accelerate left
# [-0.53623384  0.00512576] -> Accelerate right
# [-0.5300134  0.0062205] -> No accelerating
# [-0.52374476  0.0062686 ] -> No accelerating
# [-0.51747507  0.0062697 ] -> No accelerating
# [-0.5112513   0.00622377] -> No accelerating
# [-0.5051201   0.00613119] -> Accelerate left
# [-0.50012743  0.00499267] -> Accelerate left
# [-0.49631065  0.00381678] -> Accelerate left
# [-0.4936983   0.00261235] -> Accelerate right
# [-0.49030992  0.00338839] -> Accelerate right
# [-0.48617077  0.00413914] -> No accelerating
# [-0.48231176  0.00385902] -> Accelerate right
# [-0.4777616   0.00455016] -> No accelerating
# [-0.47355413  0.00420746] -> No accelerating
# [-0.4697206   0.00383354] -> Accelerate right
# [-0.46528938  0.00443121] -> Accelerate left
# [-0.46229327  0.00299611] -> Accelerate right
# [-0.45875436  0.00353891] -> Accelerate right
# [-0.4546987   0.00405564] -> No accelerating
# [-0.45115617  0.00354256] -> No accelerating
# [-0.44815266  0.00300351] -> Accelerate left
# [-0.44671017  0.00144248] -> Accelerate left
# [-4.4683924e-01 -1.2908342e-04] -> No accelerating
# [-0.44753897 -0.00069971] -> Accelerate left
# [-0.4498042  -0.00226522] -> Accelerate right
# [-0.45161834 -0.00181417] -> Accelerate left
# [-0.45496818 -0.00334983] -> No accelerating
# [-0.4588291  -0.00386093] -> No accelerating
# [-0.46317276 -0.00434366] -> Accelerate left
# [-0.46896714 -0.00579437] -> Accelerate right
# [-0.47416943 -0.00520228] -> Accelerate left
# [-0.48074105 -0.00657164] -> Accelerate right
# [-0.48663324 -0.00589219] -> Accelerate right
# [-0.4918021  -0.00516886] -> Accelerate left
# [-0.4982091  -0.00640698] -> Accelerate right
# [-0.5038063  -0.00559721] -> No accelerating
# [-0.5095519  -0.00574557] -> Accelerate right
# [-0.51440275 -0.00485089] -> Accelerate right
# [-0.5183226  -0.00391985] -> Accelerate left
# [-0.52328205 -0.00495942] -> No accelerating
# [-0.52824384 -0.0049618 ] -> No accelerating
# [-0.5331708  -0.00492696] -> No accelerating
# [-0.538026   -0.00485518] -> Accelerate left
# [-0.543773   -0.00574701] -> Accelerate right
# [-0.5483688 -0.0045958] -> Accelerate right
# [-0.551779   -0.00341019] -> Accelerate right
# [-0.5539781  -0.00219909] -> No accelerating
# [-0.5559496  -0.00197156] -> No accelerating
# [-0.55767894 -0.00172931] -> Accelerate left
# [-0.5601531  -0.00247416] -> Accelerate left
# [-0.56335366 -0.00320055] -> No accelerating
# [-0.56625676 -0.00290309] -> Accelerate left
# [-0.5698408  -0.00358403] -> Accelerate left
# [-0.5740791  -0.00423833] -> Accelerate right
# [-0.57694024 -0.00286117] -> Accelerate left
# [-0.5804031  -0.00346281] -> No accelerating
# [-0.5834419  -0.00303884] -> Accelerate right
# [-0.5850344  -0.00159242] -> Accelerate right
# [-5.8516860e-01 -1.3426151e-04] -> No accelerating
# [-5.8484370e-01  3.2489092e-04] -> Accelerate right
# [-0.58306205  0.00178165] -> Accelerate left
# [-0.5818368   0.00122526] -> No accelerating
# [-0.580177    0.00165983] -> Accelerate right
# [-0.57709485  0.00308213] -> Accelerate right
# [-0.57261324  0.00448163] -> No accelerating
# [-0.5677653   0.00484791] -> Accelerate right
# [-0.5615871  0.0061782] -> Accelerate left
# [-0.5561246   0.00546249] -> Accelerate right
# [-0.54941857  0.00670605] -> No accelerating
# [-0.5425191  0.0068995] -> Accelerate left
# [-0.53647774  0.00604133] -> Accelerate left
# [-0.5313398  0.0051379] -> Accelerate left
# ***********
# Episode: 5
# ***********
# [-0.49966642  0.        ] -> Accelerate right
# [-0.49884576  0.00082066] -> Accelerate right
# [-0.49721056  0.00163518] -> No accelerating
# [-0.49577308  0.00143748] -> No accelerating
# [-0.49454406  0.00122903] -> Accelerate right
# [-0.49253267  0.00201139] -> Accelerate left
# [-0.49175394  0.00077874] -> Accelerate left
# [-4.9221367e-01 -4.5973732e-04] -> Accelerate left
# [-0.49390844 -0.00169478] -> Accelerate right
# [-0.4948256  -0.00091716] -> Accelerate left
# [-0.4969583  -0.00213269] -> Accelerate left
# [-0.5002906  -0.00333228] -> Accelerate left
# [-0.5047975  -0.00450695] -> Accelerate right
# [-0.50844544 -0.00364789] -> Accelerate right
# [-0.5112069 -0.0027615] -> Accelerate left
# [-0.5150613  -0.00385442] -> Accelerate left
# [-0.5199798  -0.00491844] -> Accelerate right
# [-0.52392536 -0.00394558] -> Accelerate right
# [-0.52686846 -0.00294313] -> No accelerating
# [-0.52978706 -0.00291861] -> Accelerate left
# [-0.5336593 -0.0038722] -> Accelerate left
# [-0.538456   -0.00479676] -> No accelerating
# [-0.5431414  -0.00468536] -> Accelerate left
# [-0.5486803  -0.00553888] -> Accelerate left
# [-0.55503124 -0.00635094] -> Accelerate left
# [-0.5621468  -0.00711555] -> Accelerate left
# [-0.5699739  -0.00782708] -> No accelerating
# [-0.57745427 -0.00748039] -> No accelerating
# [-0.5845325  -0.00707823] -> Accelerate right
# [-0.59015626 -0.00562377] -> Accelerate left
# [-0.59628415 -0.0061279 ] -> Accelerate left
# [-0.60287124 -0.00658707] -> Accelerate right
# [-0.6078693  -0.00499811] -> Accelerate left
# [-0.61324215 -0.00537279] -> Accelerate left
# [-0.61895066 -0.00570854] -> Accelerate right
# [-0.6229538  -0.00400312] -> No accelerating
# [-0.6262227  -0.00326894] -> Accelerate right
# [-0.6277341  -0.00151136] -> No accelerating
# [-0.6284771  -0.00074299] -> Accelerate left
# [-0.6294464  -0.00096932] -> Accelerate left
# [-0.63063514 -0.00118873] -> Accelerate right
# [-6.300348e-01  6.003150e-04] -> No accelerating
# [-0.6286497   0.00138509] -> No accelerating
# [-0.62648976  0.00215999] -> Accelerate left
# [-0.62457025  0.00191948] -> No accelerating
# [-0.621905    0.00266524] -> Accelerate left
# [-0.61951315  0.00239189] -> Accelerate left
# [-0.6174118   0.00210137] -> Accelerate right
# [-0.61361605  0.00379571] -> Accelerate right
# [-0.6081534   0.00546266] -> Accelerate left
# [-0.60306334  0.00509005] -> Accelerate left
# [-0.59838295  0.0046804 ] -> No accelerating
# [-0.5931463   0.00523659] -> Accelerate left
# [-0.58839196  0.00475442] -> No accelerating
# [-0.5831546   0.00523731] -> No accelerating
# [-0.577473    0.00568161] -> Accelerate left
# [-0.5723891   0.00508391] -> Accelerate right
# [-0.56594056  0.00644853] -> Accelerate right
# [-0.5581753   0.00776524] -> Accelerate right
# [-0.54915124  0.0090241 ] -> Accelerate left
# [-0.5409357   0.00821556] -> Accelerate right
# [-0.53159016  0.00934552] -> Accelerate left
# [-0.5231847   0.00840545] -> Accelerate left
# [-0.51578236  0.00740235] -> No accelerating
# [-0.5084386   0.00734373] -> No accelerating
# [-0.50120854  0.00723007] -> No accelerating
# [-0.4941463   0.00706227] -> No accelerating
# [-0.4873046   0.00684166] -> No accelerating
# [-0.48073462  0.00656999] -> Accelerate left
# [-0.47548524  0.0052494 ] -> Accelerate right
# [-0.46959543  0.0058898 ] -> Accelerate left
# [-0.46510887  0.00448654] -> Accelerate left
# [-0.46205875  0.00305012] -> No accelerating
# [-0.4594676   0.00259118] -> No accelerating
# [-0.45735443  0.00211316] -> Accelerate left
# [-0.45673484  0.00061959] -> Accelerate left
# [-0.45761335 -0.00087853] -> Accelerate left
# [-0.45998356 -0.0023702 ] -> Accelerate left
# [-0.46382797 -0.00384442] -> Accelerate left
# [-0.46911827 -0.0052903 ] -> Accelerate right
# [-0.47381538 -0.00469709] -> Accelerate left
# [-0.47988445 -0.00606908] -> Accelerate right
# [-0.48528045 -0.005396  ] -> No accelerating
# [-0.4909632  -0.00568275] -> No accelerating
# [-0.49689034 -0.00592713] -> No accelerating
# [-0.50301754 -0.00612723] -> Accelerate left
# [-0.510299   -0.00728149] -> Accelerate right
# [-0.51668024 -0.00638121] -> Accelerate right
# [-0.5221133  -0.00543309] -> Accelerate left
# [-0.5285576  -0.00644424] -> No accelerating
# [-0.5349646  -0.00640705] -> No accelerating
# [-0.54128647 -0.00632182] -> No accelerating
# [-0.54747564 -0.00618922] -> Accelerate right
# [-0.55248594 -0.0050103 ] -> Accelerate right
# [-0.5562799  -0.00379392] -> Accelerate left
# [-0.5608291 -0.0045492] -> Accelerate right
# [-0.5640996  -0.00327055] -> Accelerate right
# [-0.56606716 -0.00196754] -> No accelerating
# [-0.5677171  -0.00164989] -> Accelerate left
# [-0.57003707 -0.00231997] -> Accelerate right
# ***********
# Episode: 6
# ***********
# [-0.52448493  0.        ] -> Accelerate right
# [-0.52347827  0.00100665] -> Accelerate right
# [-0.5214725   0.00200574] -> Accelerate right
# [-0.51848274  0.0029898 ] -> Accelerate right
# [-0.5145313   0.00395143] -> No accelerating
# [-0.5106479   0.00388343] -> Accelerate right
# [-0.5058616   0.00478632] -> Accelerate left
# [-0.5022082   0.00365336] -> No accelerating
# [-0.49871516  0.00349304] -> Accelerate right
# [-0.49440858  0.00430658] -> No accelerating
# [-0.49032065  0.00408794] -> Accelerate right
# [-0.4854819   0.00483876] -> No accelerating
# [-0.48092836  0.00455351] -> Accelerate left
# [-0.477694    0.00323436] -> Accelerate left
# [-0.47580287  0.00189116] -> No accelerating
# [-0.47426894  0.00153391] -> Accelerate right
# [-0.47210366  0.00216529] -> No accelerating
# [-0.47032306  0.00178061] -> Accelerate right
# [-0.4679403   0.00238274] -> Accelerate left
# [-0.46697307  0.00096724] -> Accelerate left
# [-4.6742848e-01 -4.5541298e-04] -> Accelerate left
# [-0.46930316 -0.0018747 ] -> Accelerate left
# [-0.4725833  -0.00328012] -> Accelerate left
# [-0.47724453 -0.00466124] -> Accelerate right
# [-0.4812523  -0.00400778] -> Accelerate left
# [-0.48657683 -0.00532452] -> Accelerate right
# [-0.49117845 -0.00460162] -> Accelerate right
# [-0.49502283 -0.00384439] -> No accelerating
# [-0.49908128 -0.00405844] -> Accelerate left
# [-0.5043234  -0.00524216] -> Accelerate left
# [-0.5107101  -0.00638664] -> No accelerating
# [-0.5171934  -0.00648329] -> Accelerate right
# [-0.5227247  -0.00553132] -> Accelerate left
# [-0.5292626  -0.00653788] -> Accelerate left
# [-0.536758  -0.0074954] -> No accelerating
# [-0.5441547  -0.00739673] -> Accelerate left
# [-0.5523974  -0.00824266] -> Accelerate left
# [-0.5614243  -0.00902694] -> Accelerate left
# [-0.5711682  -0.00974386] -> No accelerating
# [-0.58055645 -0.0093883 ] -> No accelerating
# [-0.5895197  -0.00896319] -> Accelerate right
# [-0.59699166 -0.007472  ] -> Accelerate left
# [-0.60491765 -0.00792599] -> No accelerating
# [-0.6122398  -0.00732213] -> Accelerate left
# [-0.61990494 -0.00766513] -> Accelerate right
# [-0.6258578  -0.00595284] -> No accelerating
# [-0.63105565 -0.00519787] -> Accelerate left
# [-0.63646144 -0.00540583] -> Accelerate left
# [-0.6420369  -0.00557544] -> Accelerate left
# [-0.6477426  -0.00570573] -> Accelerate right
# [-0.65153867 -0.00379603] -> Accelerate right
# [-0.6533985  -0.00185986] -> Accelerate right
# [-6.533093e-01  8.921735e-05] -> Accelerate left
# [-6.532716e-01  3.768002e-05] -> Accelerate left
# [-6.5328574e-01 -1.4118788e-05] -> No accelerating
# [-0.65235156  0.00093418] -> Accelerate left
# [-0.65147555  0.00087599] -> Accelerate left
# [-0.65066385  0.00081172] -> Accelerate right
# [-0.64792204  0.00274179] -> Accelerate left
# [-0.64526933  0.00265275] -> No accelerating
# [-0.64172417  0.00354515] -> Accelerate left
# [-0.6383115   0.00341266] -> No accelerating
# [-0.6340554   0.00425613] -> Accelerate right
# [-0.6279859   0.00606947] -> Accelerate left
# [-0.62214625  0.00583964] -> Accelerate left
# [-0.6165782   0.00556803] -> Accelerate right
# [-0.6093219   0.00725637] -> Accelerate right
# [-0.60042965  0.00889223] -> Accelerate left
# [-0.5919663   0.00846337] -> No accelerating
# [-0.58299375  0.00897254] -> Accelerate right
# [-0.5725781   0.01041565] -> Accelerate right
# [-0.56079644  0.01178167] -> Accelerate right
# [-0.54773635  0.01306007] -> No accelerating
# [-0.5344954   0.01324095] -> Accelerate left
# [-0.52217275  0.01232266] -> No accelerating
# [-0.50986075  0.01231196] -> Accelerate left
# [-0.4986518   0.01120896] -> Accelerate right
# [-0.48662978  0.01202203] -> Accelerate right
# [-0.47388446  0.01274533] -> Accelerate left
# [-0.4625106   0.01137385] -> Accelerate left
# [-0.45259234  0.00991825] -> Accelerate right
# [-0.44220263  0.01038972] -> Accelerate left
# [-0.43341732  0.0087853 ] -> No accelerating
# [-0.42530015  0.00811716] -> No accelerating
# [-0.4179096   0.00739056] -> No accelerating
# [-0.4112985   0.00661111] -> Accelerate left
# [-0.4065138  0.0047847] -> Accelerate right
# [-0.4015893   0.00492451] -> No accelerating
# [-0.39755955  0.00402973] -> Accelerate right
# [-0.39345276  0.0041068 ] -> No accelerating
# [-0.39029744  0.00315532] -> No accelerating
# [-0.38811547  0.00218199] -> Accelerate left
# [-3.8792184e-01  1.9361550e-04] -> No accelerating
# [-0.38871792 -0.0007961 ] -> Accelerate right
# [-0.38949826 -0.00078032] -> Accelerate right
# [-0.39025742 -0.00075916] -> No accelerating
# [-0.39199018 -0.00173277] -> No accelerating
# [-0.39468458 -0.00269438] -> Accelerate left
# [-0.39932188 -0.00463732] -> Accelerate right
# [-0.40386984 -0.00454795] -> Accelerate right
# ***********
# Episode: 7
# ***********
# [-0.43537813  0.        ] -> Accelerate right
# [-4.3503210e-01  3.4604265e-04] -> No accelerating
# [-4.3534252e-01 -3.1041930e-04] -> Accelerate left
# [-0.43730715 -0.00196463] -> No accelerating
# [-0.43991178 -0.00260462] -> No accelerating
# [-0.44313747 -0.0032257 ] -> No accelerating
# [-0.44696078 -0.00382331] -> Accelerate right
# [-0.45035383 -0.00339305] -> Accelerate right
# [-0.4532918  -0.00293797] -> Accelerate right
# [-0.45575318 -0.00246138] -> No accelerating
# [-0.4587199  -0.00296671] -> Accelerate left
# [-0.46317014 -0.00445024] -> Accelerate right
# [-0.46707112 -0.00390097] -> Accelerate left
# [-0.47239402 -0.0053229 ] -> No accelerating
# [-0.47809944 -0.00570543] -> No accelerating
# [-0.48414505 -0.00604562] -> Accelerate right
# [-0.4894859  -0.00534083] -> Accelerate left
# [-0.4960821  -0.00659623] -> Accelerate left
# [-0.5038845  -0.00780237] -> Accelerate right
# [-0.51083463 -0.00695014] -> Accelerate right
# [-0.51688045 -0.00604585] -> Accelerate left
# [-0.5239767  -0.00709623] -> No accelerating
# [-0.5310701 -0.0070934] -> No accelerating
# [-0.53810745 -0.00703737] -> Accelerate right
# [-0.54403603 -0.00592859] -> Accelerate left
# [-0.55081147 -0.0067754 ] -> No accelerating
# [-0.557383   -0.00657153] -> Accelerate right
# [-0.5627016  -0.00531859] -> Accelerate left
# [-0.56872755 -0.00602599] -> Accelerate right
# [-0.5734161  -0.00468855] -> No accelerating
# [-0.57773244 -0.00431631] -> No accelerating
# [-0.58164454 -0.00391209] -> Accelerate right
# [-0.5841235  -0.00247895] -> Accelerate left
# [-0.587151  -0.0030275] -> Accelerate right
# [-0.5887047  -0.00155374] -> Accelerate left
# [-0.5907733  -0.00206855] -> Accelerate left
# [-0.5933414  -0.00256814] -> Accelerate left
# [-0.5963903  -0.00304888] -> Accelerate left
# [-0.59989756 -0.00350727] -> Accelerate left
# [-0.60383755 -0.00394002] -> Accelerate left
# [-0.6081816  -0.00434402] -> Accelerate left
# [-0.61289805 -0.00471643] -> No accelerating
# [-0.6169527  -0.00405467] -> Accelerate right
# [-0.61931634 -0.00236363] -> Accelerate right
# [-0.61997193 -0.00065558] -> Accelerate left
# [-0.6209147  -0.00094281] -> Accelerate right
# [-0.620138    0.00077674] -> Accelerate right
# [-0.6176473  0.0024907] -> Accelerate right
# [-0.61346054  0.00418674] -> No accelerating
# [-0.60860795  0.00485257] -> Accelerate right
# [-0.6021247   0.00648325] -> No accelerating
# [-0.59505796  0.00706677] -> Accelerate right
# [-0.58645934  0.00859861] -> Accelerate left
# [-0.578392    0.00806728] -> Accelerate left
# [-0.5709157   0.00747638] -> Accelerate left
# [-0.5640856   0.00683007] -> No accelerating
# [-0.55695266  0.00713297] -> Accelerate right
# [-0.5485699   0.00838271] -> Accelerate right
# [-0.5390001   0.00956982] -> No accelerating
# [-0.5293148   0.00968529] -> No accelerating
# [-0.5195867   0.00972815] -> Accelerate left
# [-0.5108886   0.00869806] -> Accelerate left
# [-0.5032858   0.00760276] -> No accelerating
# [-0.49583533  0.00745051] -> Accelerate left
# [-0.48959282  0.00624252] -> No accelerating
# [-0.48360488  0.00598792] -> Accelerate left
# [-0.4789162   0.00468869] -> No accelerating
# [-0.47456163  0.00435457] -> No accelerating
# [-0.4705735   0.00398812] -> Accelerate right
# [-0.46598142  0.0045921 ] -> Accelerate right
# [-0.4608193   0.00516212] -> No accelerating
# [-0.45612526  0.00469405] -> Accelerate left
# [-0.4529338   0.00319145] -> Accelerate right
# [-0.44926837  0.00366542] -> Accelerate left
# [-0.44715583  0.00211255] -> No accelerating
# [-0.44561157  0.00154424] -> Accelerate right
# [-0.4436469   0.00196466] -> Accelerate left
# [-4.4327617e-01  3.7075521e-04] -> Accelerate left
# [-0.44450203 -0.00122585] -> Accelerate right
# [-0.44531554 -0.00081353] -> No accelerating
# [-0.4467108  -0.00139527] -> Accelerate left
# [-0.44967765 -0.00296683] -> Accelerate right
# [-0.45219433 -0.0025167 ] -> Accelerate left
# [-0.4562425  -0.00404815] -> Accelerate right
# [-0.45979238 -0.00354989] -> Accelerate left
# [-0.4648179  -0.00502552] -> No accelerating
# [-0.470282  -0.0054641] -> Accelerate right
# [-0.47514427 -0.00486227] -> Accelerate left
# [-0.48136866 -0.0062244 ] -> Accelerate right
# [-0.48690894 -0.00554028] -> No accelerating
# [-0.49272385 -0.0058149 ] -> Accelerate right
# [-0.49776998 -0.00504613] -> No accelerating
# [-0.5030096  -0.00523965] -> Accelerate right
# [-0.5074036  -0.00439397] -> Accelerate left
# [-0.512919   -0.00551539] -> Accelerate left
# [-0.51951444 -0.00659547] -> Accelerate left
# [-0.52714056 -0.0076261 ] -> Accelerate right
# [-0.5337401  -0.00659954] -> Accelerate left
# [-0.5412636  -0.00752349] -> Accelerate right
# [-0.5476547  -0.00639107] -> No accelerating
# ***********
# Episode: 8
# ***********
# [-0.50543827  0.        ] -> Accelerate right
# [-0.50457436  0.00086386] -> Accelerate left
# [-5.0485313e-01 -2.7874217e-04] -> Accelerate right
# [-0.5042724   0.00058074] -> No accelerating
# [-5.0383651e-01  4.3587276e-04] -> Accelerate right
# [-0.50254875  0.00128774] -> Accelerate left
# [-5.0241882e-01  1.2997242e-04] -> Accelerate right
# [-0.50144756  0.00097123] -> Accelerate right
# [-0.49964234  0.00180522] -> Accelerate right
# [-0.49701664  0.0026257 ] -> Accelerate right
# [-0.49359012  0.00342654] -> No accelerating
# [-0.49038833  0.00320178] -> Accelerate left
# [-0.4884352   0.00195312] -> Accelerate left
# [-0.4877453   0.00068988] -> Accelerate right
# [-0.48632383  0.0014215 ] -> No accelerating
# [-0.4851813   0.00114252] -> Accelerate right
# [-0.4833263   0.00185502] -> No accelerating
# [-0.48177257  0.00155371] -> Accelerate right
# [-0.47953174  0.00224084] -> Accelerate right
# [-0.47662044  0.0029113 ] -> No accelerating
# [-0.47406033  0.00256013] -> Accelerate left
# [-0.47287035  0.00118995] -> No accelerating
# [-0.4720594   0.00081096] -> No accelerating
# [-4.7163346e-01  4.2595065e-04] -> No accelerating
# [-4.7159567e-01  3.7787468e-05] -> Accelerate left
# [-0.47294632 -0.00135066] -> Accelerate right
# [-0.4736754  -0.00072909] -> Accelerate right
# [-4.73777533e-01 -1.02115795e-04] -> No accelerating
# [-0.4742519  -0.00047439] -> Accelerate left
# [-0.47609505 -0.00184314] -> Accelerate right
# [-0.47729325 -0.00119821] -> Accelerate left
# [-0.47983763 -0.00254439] -> Accelerate right
# [-0.4817093  -0.00187165] -> Accelerate right
# [-0.4828943 -0.001185 ] -> No accelerating
# [-0.48438382 -0.00148952] -> Accelerate left
# [-0.48716676 -0.00278296] -> Accelerate right
# [-0.4892224  -0.00205565] -> No accelerating
# [-0.49153543 -0.00231302] -> Accelerate right
# [-0.49308857 -0.00155312] -> No accelerating
# [-0.4948702  -0.00178163] -> Accelerate left
# [-0.49786702 -0.00299683] -> No accelerating
# [-0.5010567  -0.00318962] -> Accelerate right
# [-0.5034152  -0.00235856] -> No accelerating
# [-0.50592506 -0.00250985] -> Accelerate left
# [-0.5095674  -0.00364234] -> Accelerate right
# [-0.5123149  -0.00274754] -> Accelerate right
# [-0.5141471  -0.00183215] -> No accelerating
# [-0.5160501  -0.00190303] -> Accelerate right
# [-0.51700974 -0.00095964] -> Accelerate right
# [-5.1701880e-01 -9.0564645e-06] -> Accelerate left
# [-0.5180772 -0.0010584] -> No accelerating
# [-0.519177   -0.00109981] -> Accelerate left
# [-0.52131003 -0.00213297] -> No accelerating
# [-0.52346015 -0.00215014] -> No accelerating
# [-0.52561134 -0.00215118] -> Accelerate left
# [-0.52874744 -0.00313609] -> Accelerate left
# [-0.5328449  -0.00409747] -> No accelerating
# [-0.53687304 -0.00402814] -> Accelerate right
# [-0.53980166 -0.00292861] -> No accelerating
# [-0.54260874 -0.00280713] -> Accelerate right
# [-0.5442734  -0.00166463] -> Accelerate left
# [-0.5467831  -0.00250967] -> Accelerate left
# [-0.550119   -0.00333593] -> Accelerate right
# [-0.5522562  -0.00213724] -> Accelerate right
# [-0.5531788  -0.00092257] -> Accelerate left
# [-0.55487984 -0.00170101] -> Accelerate left
# [-0.5573466  -0.00246675] -> No accelerating
# [-0.55956066 -0.00221407] -> No accelerating
# [-0.56150556 -0.00194488] -> No accelerating
# [-0.56316674 -0.0016612 ] -> Accelerate left
# [-0.56553185 -0.00236513] -> No accelerating
# [-0.5675833  -0.00205146] -> Accelerate left
# [-0.5703059  -0.00272253] -> No accelerating
# [-0.5726792  -0.00237338] -> Accelerate left
# [-0.57568586 -0.0030066 ] -> Accelerate left
# [-0.5793034  -0.00361754] -> Accelerate left
# [-0.5835051  -0.00420169] -> Accelerate left
# [-0.5882599  -0.00475481] -> Accelerate left
# [-0.5935328  -0.00527289] -> Accelerate left
# [-0.599285   -0.00575222] -> Accelerate left
# [-0.6054744  -0.00618944] -> Accelerate left
# [-0.61205596 -0.00658153] -> Accelerate left
# [-0.61898184 -0.00692586] -> No accelerating
# [-0.62520206 -0.00622021] -> Accelerate right
# [-0.629672   -0.00446993] -> No accelerating
# [-0.63335973 -0.00368774] -> No accelerating
# [-0.63623905 -0.00287933] -> No accelerating
# [-0.6382896  -0.00205051] -> No accelerating
# [-0.63949674 -0.00120721] -> Accelerate right
# [-0.6388521   0.00064462] -> No accelerating
# [-0.6373602  0.0014919] -> Accelerate left
# [-0.63603157  0.00132864] -> Accelerate left
# [-0.6348756   0.00115599] -> No accelerating
# [-0.6329005   0.00197515] -> Accelerate left
# [-0.63112015  0.0017803 ] -> Accelerate left
# [-0.62954736  0.0015728 ] -> No accelerating
# [-0.6271932   0.00235411] -> Accelerate right
# [-0.62307465  0.00411862] -> Accelerate right
# [-0.61722094  0.00585366] -> No accelerating
# [-0.6106743   0.00654663] -> Accelerate right
# ***********
# Episode: 9
# ***********
# [-0.45097622  0.        ] -> No accelerating
# [-0.4515166  -0.00054037] -> Accelerate right
# [-4.5159337e-01 -7.6783261e-05] -> Accelerate left
# [-0.453206   -0.00161263] -> Accelerate right
# [-0.45434266 -0.00113666] -> Accelerate right
# [-0.45499504 -0.00065236] -> Accelerate right
# [-4.5515829e-01 -1.6325917e-04] -> No accelerating
# [-0.45583126 -0.00067296] -> Accelerate right
# [-4.5600897e-01 -1.7772635e-04] -> Accelerate left
# [-0.45769015 -0.00168118] -> Accelerate right
# [-0.45886245 -0.00117228] -> Accelerate left
# [-0.4615172  -0.00265476] -> Accelerate left
# [-0.46563488 -0.00411768] -> Accelerate right
# [-0.4691851  -0.00355023] -> Accelerate right
# [-0.47214162 -0.00295652] -> No accelerating
# [-0.47548255 -0.00334092] -> Accelerate right
# [-0.4781831  -0.00270054] -> Accelerate right
# [-0.48022318 -0.0020401 ] -> Accelerate left
# [-0.48358768 -0.0033645 ] -> Accelerate right
# [-0.48625153 -0.00266386] -> Accelerate left
# [-0.49019492 -0.00394338] -> Accelerate left
# [-0.49538842 -0.00519349] -> Accelerate left
# [-0.5017932  -0.00640482] -> Accelerate left
# [-0.5093615  -0.00756824] -> Accelerate right
# [-0.51603645 -0.00667499] -> Accelerate left
# [-0.5237682 -0.0077317] -> No accelerating
# [-0.5314986  -0.00773043] -> Accelerate left
# [-0.5401698  -0.00867119] -> Accelerate right
# [-0.54771674 -0.00754696] -> No accelerating
# [-0.555083   -0.00736623] -> Accelerate left
# [-0.5632134  -0.00813045] -> Accelerate left
# [-0.5720475  -0.00883404] -> Accelerate right
# [-0.5795194  -0.00747195] -> Accelerate left
# [-0.58757395 -0.00805451] -> No accelerating
# [-0.59515154 -0.00757764] -> No accelerating
# [-0.60219663 -0.0070451 ] -> Accelerate left
# [-0.6096577  -0.00746107] -> No accelerating
# [-0.61648047 -0.00682277] -> No accelerating
# [-0.62261564 -0.00613514] -> Accelerate left
# [-0.629019   -0.00640338] -> No accelerating
# [-0.63464487 -0.00562585] -> No accelerating
# [-0.6394532  -0.00480832] -> Accelerate right
# [-0.64241   -0.0029568] -> Accelerate left
# [-0.64549446 -0.00308447] -> Accelerate right
# [-0.64668494 -0.00119049] -> No accelerating
# [-6.4697313e-01 -2.8817865e-04] -> Accelerate left
# [-6.473570e-01 -3.838533e-04] -> Accelerate right
# [-0.6458338   0.00152316] -> Accelerate right
# [-0.64241433  0.00341951] -> Accelerate left
# [-0.6391224   0.00329188] -> Accelerate right
# [-0.63398135  0.00514106] -> Accelerate left
# [-0.6290275   0.00495388] -> Accelerate left
# [-0.624296    0.00473148] -> Accelerate left
# [-0.6198207   0.00447528] -> Accelerate right
# [-0.61363375  0.00618696] -> Accelerate right
# [-0.6057797   0.00785404] -> Accelerate right
# [-0.59631556  0.00946417] -> Accelerate left
# [-0.5873103   0.00900523] -> Accelerate left
# [-0.5788302   0.00848017] -> Accelerate left
# [-0.57093763  0.00789251] -> No accelerating
# [-0.5626913   0.00824636] -> Accelerate right
# [-0.5531524   0.00953888] -> Accelerate right
# [-0.5423922   0.01076024] -> Accelerate left
# [-0.532491    0.00990112] -> Accelerate right
# [-0.52152324  0.0109678 ] -> Accelerate left
# [-0.511571    0.00995224] -> No accelerating
# [-0.501709    0.00986205] -> Accelerate left
# [-0.49301097  0.00869799] -> Accelerate right
# [-0.48354205  0.0094689 ] -> Accelerate left
# [-0.47537285  0.0081692 ] -> Accelerate left
# [-0.4685641   0.00680877] -> Accelerate left
# [-0.4631662   0.00539788] -> No accelerating
# [-0.4582191   0.00494712] -> No accelerating
# [-0.4537592   0.00445991] -> Accelerate right
# [-0.44881925  0.00493993] -> Accelerate left
# [-0.4454355   0.00338378] -> Accelerate left
# [-0.44363257  0.00180291] -> Accelerate left
# [-4.4342366e-01  2.0890162e-04] -> No accelerating
# [-4.4381028e-01 -3.8663053e-04] -> No accelerating
# [-0.44478965 -0.00097935] -> No accelerating
# [-0.44635457 -0.00156492] -> No accelerating
# [-0.44849366 -0.00213908] -> No accelerating
# [-0.45119128 -0.00269762] -> Accelerate left
# [-0.45542768 -0.00423641] -> No accelerating
# [-0.46017182 -0.00474414] -> No accelerating
# [-0.4653888  -0.00521698] -> Accelerate right
# [-0.47004014 -0.00465134] -> Accelerate left
# [-0.47609144 -0.0060513 ] -> Accelerate left
# [-0.48349783 -0.0074064 ] -> No accelerating
# [-0.49120426 -0.00770643] -> Accelerate right
# [-0.49815327 -0.00694901] -> No accelerating
# [-0.50529295 -0.00713966] -> No accelerating
# [-0.51256984 -0.00727689] -> Accelerate left
# [-0.5209294  -0.00835959] -> Accelerate left
# [-0.530309   -0.00937961] -> Accelerate left
# [-0.5406383  -0.01032929] -> Accelerate right
# [-0.54983985 -0.00920155] -> Accelerate right
# [-0.5578448  -0.00800494] -> Accelerate right
# [-0.5645934  -0.00674855] -> No accelerating
# [-0.5710352  -0.00644186] -> No accelerating
# ***********
# Episode: 10
# ***********
# [-0.46996474  0.        ] -> Accelerate right
# [-0.46936527  0.00059948] -> Accelerate right
# [-0.46817076  0.00119452] -> No accelerating
# [-0.46739003  0.00078072] -> No accelerating
# [-4.670289e-01  3.611515e-04] -> Accelerate left
# [-0.46808997 -0.00106109] -> Accelerate left
# [-0.47056544 -0.00247548] -> Accelerate right
# [-0.472437   -0.00187156] -> Accelerate left
# [-0.47569078 -0.00325377] -> Accelerate left
# [-0.4803026  -0.00461184] -> No accelerating
# [-0.48523825 -0.00493565] -> Accelerate left
# [-0.49146098 -0.00622272] -> Accelerate right
# [-0.49692437 -0.00546338] -> Accelerate left
# [-0.5035876  -0.00666322] -> Accelerate right
# [-0.5094008  -0.00581322] -> Accelerate left
# [-0.51632047 -0.00691967] -> No accelerating
# [-0.52329475 -0.00697425] -> Accelerate right
# [-0.52927125 -0.00597653] -> No accelerating
# [-0.53520525 -0.00593399] -> No accelerating
# [-0.5410522  -0.00584696] -> Accelerate right
# [-0.5457683  -0.00471612] -> Accelerate right
# [-0.5493183  -0.00354997] -> No accelerating
# [-0.55267555 -0.00335727] -> Accelerate right
# [-0.55481505 -0.00213947] -> Accelerate left
# [-0.5577207  -0.00290569] -> No accelerating
# [-0.5603709  -0.00265022] -> Accelerate left
# [-0.5637459  -0.00337499] -> Accelerate left
# [-0.56782055 -0.00407461] -> Accelerate left
# [-0.5725644  -0.00474392] -> Accelerate left
# [-0.57794243 -0.005378  ] -> Accelerate right
# [-0.58191466 -0.00397222] -> No accelerating
# [-0.5854517  -0.00353708] -> Accelerate left
# [-0.5895276  -0.00407584] -> Accelerate right
# [-0.5921122  -0.00258459] -> Accelerate left
# [-0.59518653 -0.00307435] -> Accelerate right
# [-0.5967281  -0.00154156] -> No accelerating
# [-0.5977256  -0.00099748] -> No accelerating
# [-5.9817165e-01 -4.4610031e-04] -> No accelerating
# [-5.98063111e-01  1.08542605e-04] -> No accelerating
# [-0.5974007   0.00066239] -> Accelerate right
# [-0.59518933  0.0022114 ] -> No accelerating
# [-0.59244514  0.00274421] -> Accelerate right
# [-0.58818823  0.00425689] -> No accelerating
# [-0.58344996  0.00473829] -> No accelerating
# [-0.5782652   0.00518476] -> No accelerating
# [-0.57267225  0.00559292] -> Accelerate right
# [-0.56571263  0.00695965] -> Accelerate left
# [-0.559438    0.00627466] -> No accelerating
# [-0.552895    0.00654294] -> No accelerating
# [-0.5461326   0.00676238] -> No accelerating
# [-0.5392014   0.00693125] -> Accelerate left
# [-0.5331532   0.00604823] -> No accelerating
# [-0.52703327  0.00611988] -> Accelerate right
# [-0.5198876   0.00714564] -> No accelerating
# [-0.5127699  0.0071178] -> Accelerate right
# [-0.50473326  0.0080366 ] -> Accelerate right
# [-0.49583808  0.00889518] -> No accelerating
# [-0.48715085  0.00868722] -> No accelerating
# [-0.47873643  0.0084144 ] -> Accelerate left
# [-0.47165748  0.00707895] -> No accelerating
# [-0.4649665   0.00669097] -> No accelerating
# [-0.45871302  0.00625349] -> Accelerate left
# [-0.4539431   0.00476991] -> Accelerate right
# [-0.44869182  0.00525129] -> Accelerate left
# [-0.4449976  0.0036942] -> No accelerating
# [-0.44188747  0.00311014] -> Accelerate left
# [-0.44038406  0.00150343] -> No accelerating
# [-0.43949828  0.00088578] -> Accelerate right
# [-0.43823656  0.0012617 ] -> No accelerating
# [-0.43760812  0.00062846] -> No accelerating
# [-4.3761745e-01 -9.3452936e-06] -> No accelerating
# [-0.43826455 -0.00064708] -> Accelerate left
# [-0.44054466 -0.00228012] -> No accelerating
# [-0.44344124 -0.0028966 ] -> No accelerating
# [-0.44693327 -0.003492  ] -> Accelerate right
# [-0.4499952  -0.00306194] -> No accelerating
# [-0.4536047  -0.00360949] -> Accelerate left
# [-0.4587353 -0.0051306] -> Accelerate left
# [-0.4653493  -0.00661401] -> No accelerating
# [-0.47239795 -0.00704866] -> Accelerate left
# [-0.4808291  -0.00843116] -> No accelerating
# [-0.48958015 -0.00875105] -> No accelerating
# [-0.4985859  -0.00900575] -> No accelerating
# [-0.50777906 -0.00919317] -> Accelerate left
# [-0.51809084 -0.01031177] -> No accelerating
# [-0.52844393 -0.01035308] -> Accelerate left
# [-0.53976065 -0.01131674] -> Accelerate left
# [-0.55195624 -0.01219557] -> Accelerate right
# [-0.5629394  -0.01098315] -> Accelerate left
# [-0.5746282  -0.01168878] -> No accelerating
# [-0.5859357  -0.01130755] -> Accelerate left
# [-0.59777844 -0.01184275] -> Accelerate left
# [-0.61006945 -0.01229098] -> Accelerate right
# [-0.62071913 -0.0106497 ] -> Accelerate right
# [-0.6296507  -0.00893156] -> Accelerate left
# [-0.6388002  -0.00914952] -> Accelerate right
# [-0.6461028  -0.00730261] -> Accelerate left
# [-0.6535072  -0.00740437] -> No accelerating
# [-0.6599617  -0.00645453] -> No accelerating
# [-0.66542184 -0.0054601 ] -> Accelerate left

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.2 ptos):</strong> Ejecutar 1000 episodios con el máximo de pasos establecido en el entorno de MountainCar, tomando acciones de forma aleatoria. Almacenar la posición final del coche en cada episodio, y mostrar el resultado en un gráfico. Comentar el resultado.
# </div>

# %%
num_episodios = 1000
num_pasos = 200
pos_episodio = []

for episodio in range(num_episodios):
    obs = env.reset()
    pos_paso = []
    
    for paso in range(num_pasos):
        pos_paso.append(obs[0])
        accion = env.action_space.sample()
        new_obs, reward, done, info = env.step(accion)
        obs = new_obs
        if done:
            pos_paso.append(obs[0])
            break
    
    pos_episodio.append(pos_paso[-1])

fig, ax = plt.subplots(figsize=(12,8))
plt.scatter(range(1, num_episodios + 1), pos_episodio)
plt.title("Evolución de la posición durante {} episodios".format(num_episodios))
plt.xlabel("Episodio")
plt.ylabel("Posición")
# Out:
# Text(0, 0.5, 'Posición')

# %% [markdown]
# De la anterior ejecución podemos observar que nunca llegamos a la meta (cuando la posición es mayor que 0.5). Además, observamos que el proceso de aprendizaje es totalmente aleatorio, no hay mejora, esto es normal ya que las acciones se han tomado de forma aleatoria.
#
# Un punto interesante sería ver cuánto tarda en converger el algoritmo para llegar del estado inicial al estado final, para ello solo hay que comentar la línea de código `obs = env.rest()`, de esta forma para cada episodio vamos a partir de la posición final alcanzada en el episodio anterior.

# %% [markdown]
# ## 2. Agente DQN (2.5 ptos)

# %% [markdown]
# En este apartado implementaremos una DQN teniendo en cuenta la exploración-explotación (epsilon-*greedy*), la red objetivo, y el buffer de repetición de experiencias.

# %% [markdown]
# Definiremos el buffer como sigue:

# %%
from collections import namedtuple, deque

# %%
class experienceReplayBuffer:

    def __init__(self, memory_size=50000, burn_in=10000):
        self.memory_size = memory_size
        self.burn_in = burn_in
        self.buffer = namedtuple('Buffer', 
            field_names=['state', 'action', 'reward', 'done', 'next_state'])
        self.replay_memory = deque(maxlen=memory_size)

    def sample_batch(self, batch_size=32):
        samples = np.random.choice(len(self.replay_memory), batch_size, 
                                   replace=False)
        # Use asterisk operator to unpack deque 
        batch = zip(*[self.replay_memory[i] for i in samples])
        return batch

    def append(self, state, action, reward, done, next_state):
        self.replay_memory.append(
            self.buffer(state, action, reward, done, next_state))

    def burn_in_capacity(self):
        return len(self.replay_memory) / self.burn_in

# %% [markdown]
# Primeramente implementaremos la red neuronal, utilizando un modelo Secuencial con la siguiente configuración:
# <ul>
#     <li>Tres capas completamente conectadas (representadas en pytorch por <code>nn.Lineal</code>) con 512, 256 y 128 neuronas cada una, <code>bias=True</code>, y activación ReLU </li>
#     <li>Una capa de salida completamente conectada y <code>bias=True</code> </li>
# </ul>
#
# Usaremos el optimizador Adam para entrenar la red.

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Ejercicio (0.75 ptos):</strong> Implementar la clase <code>NeuralNet()</code>. Inicializar las variables necesarias y definir el modelo Secuencial de red neuronal indicado.
#
# -----------------------------------------------------------------------------------------------------------
# <b>Nota</b>: se os proporciona el código pre-implementado. La implementación que se pide en el enunciado está indicada en los bloques <i>TODO</i> y/o con variables igualadas a <i>None</i>.
# </div>

# %%
class NeuralNet(torch.nn.Module):  

    def __init__(self, env, learning_rate=1e-3):
        
        """
        Params
        ======
        n_inputs: tamaño del espacio de estadps
        n_outputs: tamaño del espacio de acciones
        actions: array de acciones posibles
        """
        ######################################
        ##TODO: Inicializar parámetros
        super(NeuralNet, self).__init__()
        self.n_inputs = env.observation_space.shape[0]
        self.n_outputs = env.action_space.n
        self.actions = np.arange(env.action_space.n)
        self.learning_rate = learning_rate
        
        #######################################
        ##TODO: Neural network
        self.model = torch.nn.Sequential(
            torch.nn.Linear(self.n_inputs, 512, bias=True),
            torch.nn.ReLU(),
            torch.nn.Linear(512, 256, bias=True),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 128, bias=True),
            torch.nn.ReLU(),
            torch.nn.Linear(128, self.n_outputs, bias=True),
        )
        
        #######################################
        ##TODO: Initialize optimizer
        self.optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate)


    ### e-greedy method
    def get_action(self, state, epsilon=0.05):
        if np.random.random() < epsilon:
            action = np.random.choice(self.actions)  # acción random
        else:
            qvals = self.get_qvals(state)  # acción del cálculo de Q para esta acción
            print(state)
            print(qvals)
            action= torch.max(qvals, dim=-1)[1].item()
        return action
    
    
    def get_qvals(self, state):
        if type(state) is tuple:
            print("*******************")
            print("ACTUALIZCION")
            print(state)
            state = np.array([np.ravel(s) for s in state])
            print(state)
            print("*******************")
        state_t = torch.FloatTensor(state)
        return self.model(state_t)

# %% [markdown]
# A continuación implementaremos una clase que defina el comportamiento del agente DQN teniendo en cuenta:
#     <ul>
#         <li>La exploración/explotación (decaimiento de epsilon)</li>
#         <li>La actualización y sincronización de la red principal y la red objetivo (pérdida)</li>
#     </ul>
#
#
# Consideraremos que el agente ha aprendido a realizar la tarea (i.e. el "juego" termina) cuando obtiene una media de mínimo -110 puntos durante 100 episodios consecutivos.

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (75 ptos):</strong> Implementar los siguientes puntos de la clase <code>DQNAgent()</code>:
#     <ol>
#         <li>Declarar las variables de la clase</li>
#         <li>Inicializar las variables necesarias</li>
#         <li>Implementar la acción a tomar</li>
#         <li>Actualizar la red principal según la frecuencia establecida en los hiperparámetros</li>
#         <li>Calcular la pérdida (ecuación Bellman, etc)</li>
#         <li>Sincronizar la red objetivo según la frecuencia establecida en los hiperparámetros</li>
#         <li>Calcular la media de recompensas de los últimos 100 episodios</li>
#         <li>Comprobar límite de episodios</li>
#         <li>Actualizar epsilon según: $$\textrm{max}(\epsilon · \epsilon_{\textrm{decay}}, 0.01)$$ </li>
#     </ol>
# Además, durante el proceso se deben almacenar (*):
#     <ul>
#         <li>Las recompensas obtenidas en cada paso del entrenamiento</li>
#         <li>Las recompensas medias cada 100 episodios</li>
#         <li>La pérdida durante el entrenamiento</li>
#         <li>La posición final del coche en cada episodio</li>
#         <li>La evolución de epsilon a lo largo del entrenamiento</li>
#     </ul>
#
# -----------------------------------------------------------------------------------------------------------
# <b>Nota</b>: se os proporciona el código pre-implementado. La implementación que se pide en el enunciado está indicada en los bloques <i>TODO</i> y/o con variables igualadas a <i>None</i>, salvo (*) en qué momento almacenar las variables que se indican.
# </div>

# %%
from copy import deepcopy, copy

# %%
class DQNAgent:
    
    ######################################
    ##TODO 1: Declarar variables
    def __init__(self, env, main_network, buffer, reward_threshold, epsilon=0.1, eps_decay=0.99, batch_size=32):
        
        self.env = env
        self.main_network = main_network
        self.target_network = deepcopy(main_network) 
        self.buffer = buffer
        self.epsilon = epsilon
        self.eps_decay = eps_decay
        self.batch_size = batch_size
        self.reward_threshold = reward_threshold
        self.nblock = 100 # bloque de los X últimos episodios de los que se calculará la media de recompensas
        self.initialize()
        
    ######################################
    ##TODO 2: Inicializar otras variables necesarias
    def initialize(self):
        self.update_loss = []
        self.training_rewards = []
        self.mean_training_rewards = []
        self.update_position = []
        self.history_loss = []
        self.update_epsilon = []
        self.sync_eps = []
        self.total_reward = 0
        self.step_count = 0
        self.state0 = self.env.reset()
    
    ######################################
    ##TODO 3: Tomar paso siguiente
    def take_step(self, eps, mode='train'):
        if mode == 'explore': 
            action = self.env.action_space.sample()  # acción aleatoria en el burn-in
        else:
            action = self.main_network.get_action(self.state0, eps) # acción a partir del valor de Q (elección de la acción con mejor Q)
            self.step_count += 1
            
        #TODO: tomar 'step' i obtener nuevo estado y recompensa. Guardar la experiencia en el buffer
        new_state, reward, done, _ = self.env.step(action)
        self.total_reward += reward
        self.buffer.append(self.state0, action, reward, done, new_state)
        self.state0 = new_state.copy()
        
        #TODO: resetear entorno 'if done'
        if done:
            self.update_position.append(self.state0[0]) # Guardamos la posición final de cada episodio
            self.state0 = self.env.reset()
        return done

    ## TRAINING
    def train(self, gamma=0.99, max_episodes=50000, 
              batch_size=32,
              dnn_update_frequency=4,
              dnn_sync_frequency=2000):
        
        self.gamma = gamma

        # Rellenamos el buffer con N experiencias aleatorias ()
        print("Filling replay buffer...")
        while self.buffer.burn_in_capacity() < 1:
            self.take_step(self.epsilon, mode='explore')

            
        episode = 0
        training = True
        print("Training...")
        while training:
            self.state0 = self.env.reset()
            self.total_reward = 0
            gamedone = False
            while gamedone == False:
                # El agente toma una acción
                gamedone = self.take_step(self.epsilon, mode='train')
                
                #################################################################################
                #####TODO 4:  Actualizar la red principal según la frecuencia establecida #######
                if self.step_count % dnn_update_frequency == 0:
                    self.update()
                    training = False
                    print('\nEpisode limit reached')
                    break
                    
                ########################################################################################
                ###TODO 6: Sincronizar red principal y red objetivo según la frecuencia establecida#####
                if self.step_count % dnn_sync_frequency == 0:
                    self.target_network.load_state_dict(
                        self.main_network.state_dict()
                    )
                    self.sync_eps.append(episode)
                
                if gamedone:                   
                    episode += 1
                    
                    # Guardamos la evolución de la pérdida
                    self.history_loss.append(np.mean(self.update_loss))
                        
                    self.update_loss = []
                                    
                    #######################################################################################
                    ###TODO 7: calcular la media de recompensa de los últimos X episodios, y almacenar
                    self.training_rewards.append(self.total_reward)
                    mean_rewards = np.mean(
                        self.training_rewards[-self.nblock:]
                    )
                    self.mean_training_rewards.append(mean_rewards)

                    self.update_epsilon.append(self.epsilon) # Guardamos la evolución de epsilon
                    
                    print("\rEpisode {:d} Mean Rewards {:.2f} Epsilon {}\t\t".format(
                        episode, mean_rewards, self.epsilon), end="")
                    
                    #######################################################################################
                    ### TODO 8: Comprobar que todavía quedan episodios. Parar el aprendizaje si se llega al límite
                    if episode >= max_episodes:
                        training = False
                        print('\nEpisode limit reached')
                        break
                    
                    #Termina el juego si la media de recompensas ha llegado al umbral fijado para este juego  
                    if mean_rewards >= self.reward_threshold:
                        training = False
                        print('\nEnvironment solved in {} episodes!'.format(
                            episode))
                        break
                    
                    #################################################################################
                    ######TODO 9: Actualizar epsilon según la velocidad de decaimiento fijada########
                    self.epsilon = max(self.epsilon * self.eps_decay, 0.01)

                    
    #####################################         
    #####TODO 5: cálculo de la pérdida###
    def calculate_loss(self, batch):
        # Separamos las variables de la experiencia y las convertimos a tensores 
        states, actions, rewards, dones, next_states = [i for i in batch] 
        rewards_vals = torch.FloatTensor(rewards)
        actions_vals = torch.LongTensor(np.array(actions)).reshape(-1,1)
        dones_t = torch.ByteTensor(dones)
        
        print(states)
        print("*******************")
        print(actions)
        print("*******************")
        print(actions_vals)
        print("*******************")
        print(self.main_network.get_qvals(states))
        
        # Obtenemos los valores de Q de la red principal
        qvals = torch.gather(self.main_network.get_qvals(states), 1, actions_vals)
        # Obtenemos los valores de Q objetivo. El parámetro detach() evita que estos valores actualicen la red objetivo
        qvals_next = torch.max(self.target_network.get_qvals(next_states),
                               dim=-1)[0].detach()
        qvals_next[dones_t] = 0 # 0 en estados terminales
        
        #################################################################################
        ### TODO: Calcular ecuación de Bellman
        expected_qvals = self.gamma * qvals_next + rewards_vals
        
        #################################################################################
        ### TODO: Calcular la pérdida (MSE)
        loss = torch.nn.MSELoss()(qvals, expected_qvals.reshape(-1,1))
        
        return loss

    
    def update(self):
        self.main_network.optimizer.zero_grad()  # eliminamos cualquier gradiente pasado
        batch = self.buffer.sample_batch(batch_size=self.batch_size) # seleccionamos un conjunto del buffer
        loss = self.calculate_loss(batch) # calculamos la pérdida
        loss.backward() # hacemos la diferencia para obtener los gradientes
        self.main_network.optimizer.step() # aplicamos los gradientes a la red neuronal
        # Guardamos los valores de pérdida
        self.update_loss.append(loss.detach().numpy())
        
    def plot_rewards(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.training_rewards, label='Rewards')
        plt.plot(self.mean_training_rewards, label='Mean Rewards')
        plt.axhline(self.reward_threshold, color='r', label="Reward threshold")
        plt.title("Evolución de las recompensas")
        plt.xlabel('Episode')
        plt.ylabel('Reward')
        plt.legend(loc="upper left")
        plt.show()
        
    def plot_position(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.update_position)
        plt.title("Evolución de la posición final")
        plt.xlabel('Episode')
        plt.ylabel('Position')
        plt.show()
        
    def plot_loss(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.history_loss)
        plt.title("Evolución de la pérdida")
        plt.xlabel('Episode')
        plt.ylabel('Loss')
        plt.show()
        
    def plot_epsilon(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.update_epsilon)
        plt.title("Evolución de epsilon")
        plt.xlabel('Episode')
        plt.ylabel('Epsilon')
        plt.show()

# %% [markdown]
# A continuación entrenaremos el modelo con los siguientes hiperparámetros:
#    <ul>
#         <li>Velocidad de aprendizaje: 0.001</li>
#         <li>Tamaño del batch: 32</li>
#         <li>Número de episodios: 5000</li>
#         <li>Número de episodios para rellenar el buffer: 1000</li>
#         <li>Frecuencia de actualización de la red neuronal: 3 </li>
#         <li>Frecuencia de sincronización con la red objetivo: 1000</li>
#         <li>Capacidad máxima del buffer: 10000</li>
#         <li>Factor de descuento: 0.99</li>
#         <li>Epsilon: 1, con decaimiento de 0.99</li>
#     </ul>

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.25 ptos):</strong> Declarar los hiperparámetros, cargar el modelo de red neuronal y entrenar el agente. Guardar el modelo entrenado en formato ".pth".
# </div>

# %%
# Definición de los hiperparámetros
lr = 0.001            # Velocidad de aprendizaje
BATCH_SIZE = 32       # Tamaño del batch
MAX_EPISODES = 5000   # Número de episodios
BURN_IN = 1000        # Número de episodios para rellenar el buffer
DNN_UPD = 3           # Frecuencia de actualización de la red neuronal
DNN_SYNC = 1000       # Frecuencia de sincronización con la red objetivo
MEMORY_SIZE = 10000   # Capacidad máxima del buffer
GAMMA = 0.99          # Factor de descuento
EPSILON = 1           # Epsilon
EPSILON_DECAY = 0.99   # Decaimiento de epsilon

# %%
# Carga de la red neuronal
dqn = NeuralNet(env, learning_rate=lr)

# Creación del buffer
buffer = experienceReplayBuffer(
    memory_size=MEMORY_SIZE, 
    burn_in=BURN_IN
)

# Creación del agente
agent_dqn = DQNAgent(
    env=env,
    main_network=dqn,
    buffer=buffer,
    reward_threshold=env.spec.reward_threshold,
    epsilon=EPSILON,
    eps_decay=EPSILON_DECAY,
    batch_size=BATCH_SIZE
)

# Entrenamos el agente
agent_dqn.train(
    gamma=GAMMA, 
    max_episodes=MAX_EPISODES, 
    batch_size=BATCH_SIZE,  
    dnn_update_frequency=DNN_UPD, 
    dnn_sync_frequency=DNN_SYNC
)
# Out:
# Filling replay buffer...
# Training...
# (array([-0.37166187, -0.01019357], dtype=float32), array([-0.60070693, -0.00657624], dtype=float32), array([-0.44824567,  0.01152587], dtype=float32), array([-0.5701017 ,  0.01382544], dtype=float32), array([-0.2818625,  0.0087472], dtype=float32), array([-0.4478384 , -0.00165478], dtype=float32), array([-0.479266  ,  0.00538954], dtype=float32), array([-0.4785983 , -0.01115541], dtype=float32), array([-4.8381963e-01, -2.7699696e-04], dtype=float32), array([-0.41756073,  0.00153977], dtype=float32), array([-0.33348233, -0.01348923], dtype=float32), array([-0.56208485, -0.00588145], dtype=float32), array([-0.38833496,  0.00523814], dtype=float32), array([-0.6893853 ,  0.00293179], dtype=float32), array([-0.56337124,  0.01285463], dtype=float32), array([-0.5850913 , -0.00855097], dtype=float32), array([-0.41858646, -0.0054875 ], dtype=float32), array([-0.40691543,  0.00269377], dtype=float32), array([-0.51962763, -0.01298552], dtype=float32), array([-0.6565993 ,  0.00850372], dtype=float32), array([-0.57167095, -0.01219316], dtype=float32), array([-0.4797941 , -0.00776243], dtype=float32), array([-0.57945526, -0.00799112], dtype=float32), array([-0.6318829 , -0.00385872], dtype=float32), array([-0.3830837 ,  0.00525127], dtype=float32), array([-0.50896645,  0.01444978], dtype=float32), array([-6.188067e-01,  5.121867e-04], dtype=float32), array([-0.48253393,  0.003597  ], dtype=float32), array([-0.4821486 , -0.01132501], dtype=float32), array([-0.39240444,  0.00135491], dtype=float32), array([-0.4901437 ,  0.00747864], dtype=float32), array([-0.5687006 , -0.00259034], dtype=float32))
# *******************
# (0, 2, 2, 1, 0, 1, 0, 0, 1, 0, 2, 0, 2, 2, 1, 1, 0, 0, 2, 1, 1, 1, 1, 1, 1, 1, 0, 0, 1, 1, 2, 1)
# *******************
# tensor([[0],
#         [2],
#         [2],
#         [1],
#         [0],
#         [1],
#         [0],
#         [0],
#         [1],
#         [0],
#         [2],
#         [0],
#         [2],
#         [2],
#         [1],
#         [1],
#         [0],
#         [0],
#         [2],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [0],
#         [0],
#         [1],
#         [1],
#         [2],
#         [1]])
# *******************
# *******************
# ACTUALIZCION
# (array([-0.37166187, -0.01019357], dtype=float32), array([-0.60070693, -0.00657624], dtype=float32), array([-0.44824567,  0.01152587], dtype=float32), array([-0.5701017 ,  0.01382544], dtype=float32), array([-0.2818625,  0.0087472], dtype=float32), array([-0.4478384 , -0.00165478], dtype=float32), array([-0.479266  ,  0.00538954], dtype=float32), array([-0.4785983 , -0.01115541], dtype=float32), array([-4.8381963e-01, -2.7699696e-04], dtype=float32), array([-0.41756073,  0.00153977], dtype=float32), array([-0.33348233, -0.01348923], dtype=float32), array([-0.56208485, -0.00588145], dtype=float32), array([-0.38833496,  0.00523814], dtype=float32), array([-0.6893853 ,  0.00293179], dtype=float32), array([-0.56337124,  0.01285463], dtype=float32), array([-0.5850913 , -0.00855097], dtype=float32), array([-0.41858646, -0.0054875 ], dtype=float32), array([-0.40691543,  0.00269377], dtype=float32), array([-0.51962763, -0.01298552], dtype=float32), array([-0.6565993 ,  0.00850372], dtype=float32),
#         [ 0.0457,  0.1348, -0.0057],
#         [ 0.0475,  0.1362, -0.0062],
#         [ 0.0487,  0.1368, -0.0067],
#         [ 0.0429,  0.1330, -0.0055],
#         [ 0.0472,  0.1352, -0.0063],
#         [ 0.0489,  0.1367, -0.0068],
#         [ 0.0462,  0.1348, -0.0060],
#         [ 0.0456,  0.1349, -0.0056],
#         [ 0.0431,  0.1331, -0.0054],
#         [ 0.0465,  0.1349, -0.0061],
#         [ 0.0476,  0.1361, -0.0063]], grad_fn=<AddmmBackward0>)
# *******************
# ACTUALIZCION
# (array([-0.37166187, -0.01019357], dtype=float32), array([-0.60070693, -0.00657624], dtype=float32), array([-0.44824567,  0.01152587], dtype=float32), array([-0.5701017 ,  0.01382544], dtype=float32), array([-0.2818625,  0.0087472], dtype=float32), array([-0.4478384 , -0.00165478], dtype=float32), array([-0.479266  ,  0.00538954], dtype=float32), array([-0.4785983 , -0.01115541], dtype=float32), array([-4.8381963e-01, -2.7699696e-04], dtype=float32), array([-0.41756073,  0.00153977], dtype=float32), array([-0.33348233, -0.01348923], dtype=float32), array([-0.56208485, -0.00588145], dtype=float32), array([-0.38833496,  0.00523814], dtype=float32), array([-0.6893853 ,  0.00293179], dtype=float32), array([-0.56337124,  0.01285463], dtype=float32), array([-0.5850913 , -0.00855097], dtype=float32), array([-0.41858646, -0.0054875 ], dtype=float32), array([-0.40691543,  0.00269377], dtype=float32), array([-0.51962763, -0.01298552], dtype=float32), array([-0.6565993 ,  0.00850372], dtype=float32), array([-0.57167095, -0.01219316], dtype=float32), array([-0.4797941 , -0.00776243], dtype=float32), array([-0.57945526, -0.00799112], dtype=float32), array([-0.6318829 , -0.00385872], dtype=float32), array([-0.3830837 ,  0.00525127], dtype=float32), array([-0.50896645,  0.01444978], dtype=float32), array([-6.188067e-01,  5.121867e-04], dtype=float32), array([-0.48253393,  0.003597  ], dtype=float32), array([-0.4821486 , -0.01132501], dtype=float32), array([-0.39240444,  0.00135491], dtype=float32), array([-0.4901437 ,  0.00747864], dtype=float32), array([-0.5687006 , -0.00259034], dtype=float32))
# [[-3.71661872e-01 -1.01935668e-02]
#  [-6.00706935e-01 -6.57623820e-03]
#  [-4.48245674e-01  1.15258675e-02]
#  [-5.70101678e-01  1.38254436e-02]
#  [-2.81862497e-01  8.74719769e-03]
#  [-4.47838396e-01 -1.65478385e-03]
#  [-4.79265988e-01  5.38954325e-03]
#  [-4.78598297e-01 -1.11554125e-02]
#  [-4.83819634e-01 -2.76996958e-04]
#  [-4.17560726e-01  1.53977494e-03]
#  [-3.33482325e-01 -1.34892324e-02]
#  [-5.62084854e-01 -5.88144735e-03]
#  [-3.88334960e-01  5.23813535e-03]
#  [-6.89385295e-01  2.93178507e-03]
#  [-5.63371241e-01  1.28546301e-02]
#  [-5.85091293e-01 -8.55096988e-03]
#  [-4.18586463e-01 -5.48749883e-03]
#  [-4.06915426e-01  2.69377045e-03]
#  [-5.19627631e-01 -1.29855229e-02]
#  [-6.56599283e-01  8.50372203e-03]
#  [-5.71670949e-01 -1.21931555e-02]
#  [-4.79794115e-01 -7.76243350e-03]
#  [-5.79455256e-01 -7.99111836e-03]
#  [-6.31882906e-01 -3.85871809e-03]
#  [-3.83083701e-01  5.25127025e-03]
#  [-5.08966446e-01  1.44497752e-02]
#  [-6.18806720e-01  5.12186729e-04]
#  [-4.82533932e-01  3.59700178e-03]
#  [-4.82148588e-01 -1.13250120e-02]
#  [-3.92404437e-01  1.35491043e-03]
#  [-4.90143687e-01  7.47863716e-03]
#  [-5.68700612e-01 -2.59033777e-03]]
# *******************
# *******************
# ACTUALIZCION
# (array([-0.38395593, -0.01229404], dtype=float32), array([-0.60570997, -0.00500307], dtype=float32), array([-0.43628016,  0.01196552], dtype=float32), array([-0.5559286 ,  0.01417308], dtype=float32), array([-0.27577353,  0.00608897], dtype=float32), array([-0.4500565 , -0.00221811], dtype=float32), array([-0.47520798,  0.00405803], dtype=float32), array([-0.49109018, -0.01249189], dtype=float32), array([-0.48439425, -0.00057463], dtype=float32), array([-4.1780287e-01, -2.4216482e-04], dtype=float32), array([-0.34732136, -0.01383905], dtype=float32), array([-0.5686783 , -0.00659344], dtype=float32), array([-0.3830837 ,  0.00525127], dtype=float32), array([-0.6842607 ,  0.00512455], dtype=float32), array([-0.55021906,  0.01315222], dtype=float32), array([-0.5931837 , -0.00809239], dtype=float32), array([-0.4258486 , -0.00726213], dtype=float32), array([-0.40607902,  0.00083641], dtype=float32), array([-0.5316429 , -0.01201531], dtype=float32), array([-0.6471243 ,  0.00947497], dtype=float32), array([-0.5835048 , -0.01183386], dtype=float32), array([-0.48788413, -0.00809002], dtype=float32), array([-0.5870294 , -0.00757415], dtype=float32), array([-0.6349437, -0.0030608], dtype=float32), array([-0.37885535,  0.00422834], dtype=float32), array([-0.4946264 ,  0.01434007], dtype=float32), array([-6.1859012e-01,  2.1657688e-04], dtype=float32), array([-0.48024416,  0.00228979], dtype=float32), array([-0.49378368, -0.01163509], dtype=float32), array([-0.39200827,  0.00039616], dtype=float32), array([-0.48191553,  0.00822815], dtype=float32), array([-0.5709537 , -0.00225311], dtype=float32))
# [[-3.8395593e-01 -1.2294042e-02]
#  [-6.0570997e-01 -5.0030709e-03]
#  [-4.3628016e-01  1.1965520e-02]
#  [-5.5592859e-01  1.4173085e-02]
#  [-2.7577353e-01  6.0889684e-03]
#  [-4.5005649e-01 -2.2181075e-03]
#  [-4.7520798e-01  4.0580267e-03]
#  [-4.9109018e-01 -1.2491892e-02]
#  [-4.8439425e-01 -5.7463290e-04]
#  [-4.1780287e-01 -2.4216482e-04]
#  [-3.4732136e-01 -1.3839047e-02]
#  [-5.6867832e-01 -6.5934425e-03]
#  [-3.8308370e-01  5.2512703e-03]
#  [-6.8426073e-01  5.1245517e-03]
#  [-5.5021906e-01  1.3152217e-02]
#  [-5.9318370e-01 -8.0923876e-03]
#  [-4.2584860e-01 -7.2621275e-03]
#  [-4.0607902e-01  8.3640846e-04]
#  [-5.3164291e-01 -1.2015306e-02]
#  [-6.4712429e-01  9.4749685e-03]
#  [-5.8350480e-01 -1.1833863e-02]
#  [-4.8788413e-01 -8.0900239e-03]
#  [-5.8702940e-01 -7.5741527e-03]
#  [-6.3494372e-01 -3.0607956e-03]
#  [-3.7885535e-01  4.2283428e-03]
#  [-4.9462640e-01  1.4340068e-02]
#  [-6.1859012e-01  2.1657688e-04]
#  [-4.8024416e-01  2.2897942e-03]
#  [-4.9378368e-01 -1.1635087e-02]
#  [-3.9200827e-01  3.9616055e-04]
#  [-4.8191553e-01  8.2281455e-03]
#  [-5.7095373e-01 -2.2531052e-03]]
# *******************
#
# Episode limit reached
# <ipython-input-32-ff4aa1f3ca69>:156: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen\native\TensorAdvancedIndexing.cpp:1273.)
#   qvals_next[dones_t] = 0 # 0 en estados terminales

# %%
# Guardamos el modelo entrenado
trained_model = {
    "state_dic" : agent_dqn.main_network.state_dict()
}
torch.save(trained_model, "DQN.pth")

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.25 ptos):</strong> Representar:
#     <ol>
#         <li>Gráfico con las recompensas obtenidas a lo largo del entrenamieno, la evolución de las recompensas medias cada 100 episodios, y el umbral de recompensa establecido por el entorno.</li>
#         <li>Gráfico con la posición final del coche en cada episodio</li>
#         <li>Gráfico con la evolución de la perdida a lo largo del entrenamiento</li>
#         <li>Gráfico con la evolución de epsilon a lo largo del entrenamiento</li>
#     </ol>
#
# Comentar los resultados obtenidos.
# </div>

# %%
agent_dqn.plot_rewards()
agent_dqn.plot_position()
agent_dqn.plot_loss()
agent_dqn.plot_epsilon()

# %% [markdown]
# Respecto al primer gráfico, podemos ver el cómo han ido evolucionando las recompensas en cada episodio y las recompensas medias de los últimos 100 episodios junto con el umbral. Como podemos ver sigue una tendencia al alza, es decir, a partir del episodio 180 el agente empieza a aprender, esto se debe a que a medida que avanza el tiemmpo se reduce la probabilidad de seleccionar acciones aleatorias, por lo tanto cada vez el modelo va siendo mejor. Estas recompensas van mejorando hasta el episodio 1073 en el que la recompensa media ha alcanzdo el umbral.
#
# En cuanto al segundo gráfico, podemos ver el cómo ha evolucionado la posición final en cada episodio, como es lógico al principio el modelo es muy aleatorio ya que busca aprender diferentes "situaciones" y no se llega a la posición objetivo (mayor de 0.5). A partir del episodio 180 vemos que el agente empieza a aprender, y aunque hay muchos episodios en los que no se llega a la posición final es a partir de este momento en el que empieza a ser más frecuente llegar dicha posición. A medida que van pasando los episodios el agente va aprendiendo mejor y una vez alcanzado el episodio 900 el agente ya consigue alcanzar la posición objetivo en todos los episodios.
#
# Respecto al tercer gráfico, se puede analizar la pérdida que va teniendo nuestro modelo, al principio es muy pequeña (es lógico ya que no ha ido variando nuestra red neuronal), a medida que se van ajustando los pesos en cada episodio vemos que la périda es muy inestable y grande, pero es a partir del episodio 850 en el que dicha pérdida se consigue reducir a niveles muy bajos, esto quiere decir que nuestra red neuronal ya está ajustada.
#
# Finalmente, el cuarto gráfico podemos ver la evolución de epsilon, cuanto mayor es epsilon más probabilidades de que la acción elegida por el modelo sea aleatoria, vemos que a partir del episodio 400 epsilon se mantiene estable, es decir, ya solamente busca mejorar el modelo que se tiene, y haciendo esa búsqueda nos permite llegar a una solución en 1073 episodios.

# %% [markdown]
# Una vez entrenado el agente, nos interesa comprobar cómo de bien ha aprendido y si es capaz de conseguir que el coche llegue a su objetivo. Para ello, recuperamos el modelo entrenado y dejamos que el agente tome acciones aleatorias según ese modelo y observamos su comportamiento.

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.5 ptos):</strong> Cargar el modelo entrenado y ejecutar el agente entrenado durante 100 episodios consecutivos. Almacenar la posición final del agente en cada episodio, y calcular la suma de recompensas por cada episodio. Mostrar:
#     <ul>
#         <li>un gráfico con la suma de las recompensas respecto de los episodios, incluyendo el umbral de recompensa establecido por el entorno</li>
#         <li> un gráfico con la posición final del coche en cada episodio</li>
#     </ul>
#
# Comentar los resultados obtenidos.
#
# ---------------------------------------------------------------------------------------------------
# <i>Opcional</i>: visualizar los episodios con <code>env.render()</code>, sólo posible en local. Esta visualización ralentiza el proceso unos segundos por episodio.
# </div>

# %%
# Carga del modelo entrenado
modelo = torch.load("DQN.pth")['state_dic']
dqn.load_state_dict(modelo)

pos_episodio = []
rew_episodio = []
for episodio in range(100):
    obs = env.reset()
    pos_paso = []
    rew_paso = 0
    
    pos_paso.append(obs[0])
    
    while True:
        
        accion = dqn.get_action(obs) # USO DEL MODELO
        new_obs, reward, done, info = env.step(accion)
        
        obs = new_obs
        pos_paso.append(obs[0])
        rew_paso += reward
        
        if done:
            break
    pos_episodio.append(pos_paso[-1])
    rew_episodio.append(rew_paso)

plt.figure(figsize=(12,8))
plt.plot(rew_episodio, label='Rewards')
plt.axhline(env.spec.reward_threshold, color='r', label="Reward threshold")
plt.title("Evolución de las recompensas")
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.legend(loc="upper left")
plt.show()

plt.figure(figsize=(12,8))
plt.plot(pos_episodio)
plt.title("Evolución de la posición")
plt.xlabel('Episode')
plt.ylabel('Position')
plt.show()

# %% [markdown]
# Respecto a cómo se comporta el agente, vemos de las dos anteriores gráficas que no es el mejor agente del mundo, es decir, en 100 episodios sí que es capaz de llegar varias veces a la posición objetivo (o estar muy cerca de la misma), pero también hay otras tantas veces que no, por lo que nos hace pensar que tal y como están definidos los hiperparámetros no son los más adecuados para este modelo.
#
# En cuanto a las recompensas que se obtienen, vemos que ninguna llega al umbral, es verdad que son mejores recompensas que la peor de todas que sería -200, pero en ningún episodio se consigue llegar a una recompensa de mínimo -110.
#
# Cabe mencionar que este algoritmo se ha ejecutado muchas veces y es muy aleatorio la calidad del propio modelo, con ello me refiero a que hay veces en los que el agente entrenado es muy bueno pero otras veces como esta en los que no están bueno.

# %% [markdown]
# ## 3. Agente DDQN (2.5 ptos)

# %% [markdown]
# En este apartado implementaremos una doble DQN con la misma red neuronal y características de la DQN del apartado anterior.

# %% [markdown]
# Recordemos que con la doble DQN, es la red principal la que elije la acción con mayor valor de Q, y la red objetivo la que proporciona el valor objetivo de Q para esa
# acción, es decir, la que dirá qué recompensa tiene esa acción elegida por la red principal.
#
# Siguiendo el mismo esquema que en el ejercicio anterior, a continuación implementaremos una clase que defina el entrenamiento del agente teniendo en cuenta:
#     <ul>
#         <li>La exploración/explotación (decaimiento de epsilon)</li>
#         <li>La actualización y sincronización de la red principal y la red objetivo (pérdida)</li>
#     </ul>
#
# Consideraremos que el agente ha aprendido a realizar la tarea (i.e. el "juego" termina) cuando obtiene una media de mínimo -110 puntos durante 100 episodios consecutivos.

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (1 pto):</strong> Implementar los siguientes puntos de la clase <code>DDQNAgent()</code> siguiendo el mismo esquema de implementación realizado con el método <code>DQNAgent()</code>
# </div>

# %%
class DDQNAgent:

    ######################################
    ##TODO 1: Declarar variables
    def __init__(self, env, main_network, buffer, reward_threshold, epsilon=0.1, eps_decay=0.99, batch_size=32):
        
        self.env = env
        self.main_network = main_network
        self.target_network = deepcopy(main_network) 
        self.buffer = buffer
        self.epsilon = epsilon
        self.eps_decay = eps_decay
        self.batch_size = batch_size
        self.reward_threshold = reward_threshold
        self.nblock = 100 # bloque de los X últimos episodios de los que se calculará la media de recompensas
        self.initialize()
        
    ######################################
    ##TODO 2: Inicializar otras variables necesarias
    def initialize(self):
        self.update_loss = []
        self.training_rewards = []
        self.mean_training_rewards = []
        self.update_position = []
        self.history_loss = []
        self.update_epsilon = []
        self.sync_eps = []
        self.total_reward = 0
        self.step_count = 0
        self.state0 = self.env.reset()
    
    ######################################
    ##TODO 3: Tomar paso siguiente
    def take_step(self, eps, mode='train'):
        if mode == 'explore': 
            action = self.env.action_space.sample()  # acción aleatoria en el burn-in
        else:
            action = self.main_network.get_action(self.state0, eps) # acción a partir del valor de Q (elección de la acción con mejor Q)
            self.step_count += 1
            
        #TODO: tomar 'step' i obtener nuevo estado y recompensa. Guardar la experiencia en el buffer
        new_state, reward, done, _ = self.env.step(action)
        self.total_reward += reward
        self.buffer.append(self.state0, action, reward, done, new_state)
        self.state0 = new_state.copy()
        
        #TODO: resetear entorno 'if done'
        if done:
            self.update_position.append(self.state0[0]) # Guardamos la posición final de cada episodio
            self.state0 = self.env.reset()
        return done

    ## TRAINING
    def train(self, gamma=0.99, max_episodes=50000, 
              batch_size=32,
              dnn_update_frequency=4,
              dnn_sync_frequency=2000):
        
        self.gamma = gamma

        # Rellenamos el buffer con N experiencias aleatorias ()
        print("Filling replay buffer...")
        while self.buffer.burn_in_capacity() < 1:
            self.take_step(self.epsilon, mode='explore')

            
        episode = 0
        training = True
        print("Training...")
        while training:
            self.state0 = self.env.reset()
            self.total_reward = 0
            gamedone = False
            while gamedone == False:
                # El agente toma una acción
                gamedone = self.take_step(self.epsilon, mode='train')
                
                #################################################################################
                #####TODO 4:  Actualizar la red principal según la frecuencia establecida #######
                if self.step_count % dnn_update_frequency == 0:
                    self.update()
                    
                ########################################################################################
                ###TODO 6: Sincronizar red principal y red objetivo según la frecuencia establecida#####
                if self.step_count % dnn_sync_frequency == 0:
                    self.target_network.load_state_dict(
                        self.main_network.state_dict()
                    )
                    self.sync_eps.append(episode)
                
                if gamedone:                   
                    episode += 1
                    
                    # Guardamos la evolución de la pérdida
                    self.history_loss.append(np.mean(self.update_loss))
                        
                    self.update_loss = []
                                    
                    #######################################################################################
                    ###TODO 7: calcular la media de recompensa de los últimos X episodios, y almacenar
                    self.training_rewards.append(self.total_reward)
                    mean_rewards = np.mean(
                        self.training_rewards[-self.nblock:]
                    )
                    self.mean_training_rewards.append(mean_rewards)

                    self.update_epsilon.append(self.epsilon) # Guardamos la evolución de epsilon
                    
                    print("\rEpisode {:d} Mean Rewards {:.2f} Epsilon {}\t\t".format(
                        episode, mean_rewards, self.epsilon), end="")
                    
                    #######################################################################################
                    ### TODO 8: Comprobar que todavía quedan episodios. Parar el aprendizaje si se llega al límite
                    if episode >= max_episodes:
                        training = False
                        print('\nEpisode limit reached')
                        break
                    
                    #Termina el juego si la media de recompensas ha llegado al umbral fijado para este juego  
                    if mean_rewards >= self.reward_threshold:
                        training = False
                        print('\nEnvironment solved in {} episodes!'.format(
                            episode))
                        break
                    
                    #################################################################################
                    ######TODO 9: Actualizar epsilon según la velocidad de decaimiento fijada########
                    self.epsilon = max(self.epsilon * self.eps_decay, 0.01)

    #####################################         
    #####TODO 5: cálculo de la pérdida###
    def calculate_loss(self, batch):
        # Separamos las variables de la experiencia y las convertimos a tensores
        states, actions, rewards, dones, next_states = [i for i in batch]
        
        rewards_vals = torch.FloatTensor(rewards)
        actions_vals = torch.LongTensor(np.array(actions)).reshape(-1,1)
        dones_t = torch.ByteTensor(dones)
        
        # Obtenemos los valores de Q de la red principal
        qvals = torch.gather(self.main_network.get_qvals(states), 1, actions_vals)
        
        # Obtenemos las mejores acciones de los siguientes estados según la red principal
        actions_next = torch.argmax(self.main_network.get_qvals(next_states),
                                dim=-1).reshape(-1,1)
        
        # Obtenemos los valores de Q objetivo dependiendo de la acción de la red principal
        qvals_next = torch.gather(self.target_network.get_qvals(next_states), 1, 
                                  actions_next).detach().reshape(-1)
        qvals_next[dones_t] = 0 # 0 en estados terminales
        
        #################################################################################
        ### TODO: Calcular ecuación de Bellman
        expected_qvals = self.gamma * qvals_next + rewards_vals
        #################################################################################
        ### TODO: Calcular la pérdida (MSE)
        loss = torch.nn.MSELoss()(qvals, expected_qvals.reshape(-1,1))
        
        return loss

    
    def update(self):
        self.main_network.optimizer.zero_grad()  # eliminamos cualquier gradiente pasado
        batch = self.buffer.sample_batch(batch_size=self.batch_size) # seleccionamos un conjunto del buffer
        loss = self.calculate_loss(batch) # calculamos la pérdida
        loss.backward() # hacemos la diferencia para obtener los gradientes
        self.main_network.optimizer.step() # aplicamos los gradientes a la red neuronal
        # Guardamos los valores de pérdida
        self.update_loss.append(loss.detach().numpy())
        
    def plot_rewards(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.training_rewards, label='Rewards')
        plt.plot(self.mean_training_rewards, label='Mean Rewards')
        plt.axhline(self.reward_threshold, color='r', label="Reward threshold")
        plt.title("Evolución de las recompensas")
        plt.xlabel('Episode')
        plt.ylabel('Reward')
        plt.legend(loc="upper left")
        plt.show()
        
    def plot_position(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.update_position)
        plt.title("Evolución de la posición final")
        plt.xlabel('Episode')
        plt.ylabel('Position')
        plt.show()
        
    def plot_loss(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.history_loss)
        plt.title("Evolución de la pérdida")
        plt.xlabel('Episode')
        plt.ylabel('Loss')
        plt.show()
        
    def plot_epsilon(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.update_epsilon)
        plt.title("Evolución de epsilon")
        plt.xlabel('Episode')
        plt.ylabel('Epsilon')
        plt.show()

# %% [markdown]
# A continuación entrenaremos el modelo con los mismos hiperparámetros que con la DQN.

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.25 ptos):</strong> Entrenar el agente. Guardar el modelo entrenado en formato ".pth".
# </div>

# %%
# Carga de la red neuronal
ddqn = NeuralNet(env, learning_rate=lr)

# Creación del buffer
buffer = experienceReplayBuffer(
    memory_size=MEMORY_SIZE, 
    burn_in=BURN_IN
)

# Creación del agente
agent_ddqn = DDQNAgent(
    env=env,
    main_network=ddqn,
    buffer=buffer,
    reward_threshold=env.spec.reward_threshold,
    epsilon=EPSILON,
    eps_decay=EPSILON_DECAY,
    batch_size=BATCH_SIZE
)

# Entrenamos el agente
agent_ddqn.train(
    gamma=GAMMA, 
    max_episodes=MAX_EPISODES, 
    batch_size=BATCH_SIZE,  
    dnn_update_frequency=DNN_UPD, 
    dnn_sync_frequency=DNN_SYNC
)
# Out:
# Filling replay buffer...
# Training...
# <ipython-input-23-1f4fd331d673>:150: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen\native\TensorAdvancedIndexing.cpp:1273.)
#   qvals_next[dones_t] = 0 # 0 en estados terminales
# Episode 1557 Mean Rewards -109.76 Epsilon 0.01		118606165716
# Environment solved in 1557 episodes!

# %%
# Guardamos el modelo entrenado
trained_model = {
    "state_dic" : agent_ddqn.main_network.state_dict()
}
torch.save(trained_model, "DDQN.pth")

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.25 ptos):</strong> Representar:
#     <ol>
#         <li>Gráfico con las recompensas obtenidas a lo largo del entrenamieno, la evolución de las recompensas medias cada 100 episodios, y el umbral de recompensa establecido por el entorno</li>
#         <li>Gráfico con la posición final del coche en cada episodio</li>
#         <li>Gráfico con la evolución de la perdida a lo largo del entrenamiento</li>
#         <li>Gráfico con la evolución de epsilon a lo largo del entrenamiento</li>
#   </ol>
# Comentar los resultados obtenidos.
# </div>

# %%
agent_ddqn.plot_rewards()
agent_ddqn.plot_position()
agent_ddqn.plot_loss()
agent_ddqn.plot_epsilon()

# %% [markdown]
# Respecto al primer gráfico, observamos la evolución de las recompensas y recompensas medias que hay durante la ejecución del agente junto con el umbral. En este caso vemos que se han necesitado más episodios para alcanzar el umbral (-110), para ser más exactos se han necesitado 1557 episodios. Al igual que en el ejercicio anterior, en los primeros episodios las acciones a elegir son aleatorias mayoritariamente, por lo que las recompensas obtenidos no son muy buenas. A medida que va avanzando el aprendizaje del agente dichas recompensas son mejores. Un detalle curioso es el ver que al llegar al episodio 1050 casi se llega al umbral, similar al ejercicio anterior, pero esta vez ha habido una "caída" en las recompensas, ya que a diferencia de DQN en DDQN no se tiende a sobreestimar los valores de Q, en DQN la red objetivo se encarga de ver qué acción es mejor y calcular su Q, mientras que en DDQN la red objetivo solo calcula el valor de Q de la mejor acción según la red principal, con esto se consigue un mejor rendimiento en el modelo.
#
# En cuanto al segundo gráfico, podemos ver la posición final alcanzada en cada episodio, como es lógico al principio es muy aleatorio y no se llega a la posición objetivo (mayor que 0.5), pero a medida que el agente va aprendiendo reduciendo el valor de epsilon conseguimos que a partir del episodio 650 se consiga llegar ya de manera frecuente a la posición objetivo. Sin embargo, debido a la aletoriedad y del ajuste del modelo no es hasta el episodio 1400 en el que se estabiliza la posición final.
#
# Respecto al tercer gráfico, observamos la evolución de la pérdida en el modelo, al principio es muy pequeña (es lógico ya que no ha ido variando nuestra red neuronal), a medida que se van ajustando los pesos en cada episodio vemos que la périda es muy inestable y grande, pero es a partir del episodio 1100 en el que dicha pérdida se consigue reducir a niveles muy bajos, esto quiere decir que nuestra red neuronal ya está ajustada.
#
# En cuanto all cuarto gráfico podemos ver la evolución de epsilon, cuanto mayor es epsilon más probabilidades de que la acción elegida por el modelo sea aleatoria, vemos que a partir del episodio 450 epsilon se mantiene estable, es decir, ya solamente busca mejorar el modelo que se tiene, y haciendo esa búsqueda nos permite llegar a una solución en 1557 episodios.

# %% [markdown]
# Una vez entrenado el agente, nos interesa comprobar cómo de bien ha aprendido, si el "robot" es capaz de realizar las tareas aprendidas. Para ello, recuperamos el modelo entrenado y dejamos que el agente tome acciones aleatorias según ese modelo y observamos su comportamiento.

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.5 ptos):</strong> Cargar el modelo entrenado y ejecutar el agente entrenado durante 100 episodios consecutivos. Almacenar la posición final del agente en cada episodio, y calcular la suma de recompensas por cada episodio. Mostrar:
#     <ul>
#         <li>un gráfico con la suma de las recompensas respecto de los episodios, incluyendo el umbral de recompensa establecido por el entorno</li>
#         <li> un gráfico con la posición final del coche en cada episodio</li>
#     </ul>
#
# Comentar los resultados obtenidos.
#
# ---------------------------------------------------------------------------------------------------
# <i>Opcional</i>: visualizar los episodios con <code>env.render()</code>, sólo posible en local. Esta visualización ralentiza el proceso unos segundos por episodio.
# </div>

# %%
# Carga del modelo entrenado
modelo = torch.load("DDQN.pth")['state_dic']
ddqn.load_state_dict(modelo)

pos_episodio = []
rew_episodio = []
for episodio in range(100):
    obs = env.reset()
    pos_paso = []
    rew_paso = 0
    
    pos_paso.append(obs[0])
    
    while True:
        
        accion = ddqn.get_action(obs) # USO DEL MODELO
        new_obs, reward, done, info = env.step(accion)
        
        obs = new_obs
        pos_paso.append(obs[0])
        rew_paso += reward
        
        if done:
            break
    pos_episodio.append(pos_paso[-1])
    rew_episodio.append(rew_paso)

plt.figure(figsize=(12,8))
plt.plot(rew_episodio, label='Rewards')
plt.axhline(env.spec.reward_threshold, color='r', label="Reward threshold")
plt.title("Evolución de las recompensas")
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.legend(loc="upper left")
plt.show()


plt.figure(figsize=(12,8))
plt.plot(pos_episodio)
plt.title("Evolución de la posición")
plt.xlabel('Episode')
plt.ylabel('Position')
plt.show()

# %% [markdown]
# En este caso vemos que DDQN se comporta mejor que DQN, es decir, este modelo ha conseguido aprender mejor que el modelo del ejercicio anterior.
#
# Esta mejora la podemos observar en que ahora en la gran mayoría de episodios se alcanza o se supera el umbral, es cierto que hay episodios en los que no, pero este número es muy pequeño comparado con el ejercicio anterior (en ningún episodio se conseguía alcanzar el umbral).
#
# Por otro lado, en DDQN vemos que en la gran mayoría de episodios la posición final supera la objetivo (0.5), por lo tanto vemos que hay un comportamiento idóneo. Es verdad que no en todos los episodios se consigue alcanzar el valor objetivo, pero están muy próximon a éste.

# %% [markdown]
# ## 4. REINFORCE con línea de base (2 ptos)

# %% [markdown]
# En este apartado implementaremos un modelo basado en Gradientes de Política, el método de REINFORCE con línea de base.

# %% [markdown]
# Utilizaremos un modelo Secuencial con la siguiente configuración:
# <ul>
#     <li>Tres capas completamente conectadas de 64, 32 y 16 neuronas respectivamente, <code>bias=True</code>, y activación tangencial</li>
#     <li>Una capa de salida completamente conectada, <code>bias=True</code>, y activación Softmax (dim=-1)
# </ul>
#
# Usaremos el optimizador Adam para entrenar la red.

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.75 ptos):</strong> Implementar la clase <code>PGReinforce()</code>. Inicializar las variables necesarias y definir el modelo Secuencial de red neuronal indicado.
#
# -----------------------------------------------------------------------------------------------------------
# <b>Nota</b>: se os proporciona el código pre-implementado. La implementación que se pide en el enunciado está indicada en los bloques <i>TODO</i> y/o con variables igualadas a <i>None</i>.
# </div>

# %%
class NeuralNetReinforce(torch.nn.Module):

    def __init__(self, env, learning_rate=1e-3):
        """
        Params
        ======
        n_inputs: tamaño del espacio de estadps
        n_outputs: tamaño del espacio de acciones
        learning_rate: velocidad aprendizaje
        """       
        super(NeuralNetReinforce, self).__init__()
        
        ###################################
        ####TODO: Inicializar parámetros#### 
        self.n_inputs = env.observation_space.shape[0]
        self.n_outputs = env.action_space.n
        self.learning_rate = learning_rate
        
        #######################################
        ##TODO: Construcción de la red neuronal 
        self.model = torch.nn.Sequential(
            torch.nn.Linear(self.n_inputs, 64, bias=True), 
            torch.nn.Tanh(),
            torch.nn.Linear(64, 32, bias=True), 
            torch.nn.Tanh(),
            torch.nn.Linear(32, 16, bias=True), 
            torch.nn.Tanh(), 
            torch.nn.Linear(16, self.n_outputs, bias=True),
            torch.nn.Softmax(dim=-1)
        )
        
        #######################################
        ##TODO: Inicializar el optimizador
        self.optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate)

        
    #Obtención de las probabilidades de las posibles acciones       
    def get_action_prob(self, state):
        action_probs = self.model(torch.FloatTensor(state))
        return action_probs

# %% [markdown]
# A continuación definiremos el comportamiento del agente. En este caso no tendremos en cuenta el umbral de recompensa en la finalización del aprendizaje, sino **dejaremos al agente realizar el máximo de episodios establecido**.

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.75 ptos):</strong> Implementar la clase <code>reinforceAgent()</code> teniendo en cuenta los siguientes puntos:
#     <ol>
#         <li>Inicializar parámetros</li>
#         <li>Inicializar las variables necesarias</li>
#         <li>Implementar la acción a tomar</li>
#         <li>Calcular el <i>discounted rewards</i> usando como línea de base la media del retorno estandarizada</li>
#         <li>Calcular la media de recompensas de los últimos 100 episodios</li>
#         <li>Actualizar red, almacenar pérdida y resetear variables cuando se completa el batch</li>
#         <li>Implementar la pérdida por actualización</li>
#         <li>Hacer las comprobaciones necesarias de fin de episodio</li>
#     </ol>
# Además, durante el proceso se deben almacenar (*):
#     <ul>
#         <li>Las recompensas obtenidas en cada paso del entrenamiento</li>
#         <li>Las recompensas medias cada 100 episodios</li>
#         <li>La posición final del coche en cada episodio</li>
#         <li>La pérdida durante el entrenamiento</li>
#     </ul>
#
#
# -----------------------------------------------------------------------------------------------------------
# <b>Nota</b>: se os proporciona el código pre-implementado. La implementación que se pide en el enunciado está indicada en los bloques <i>TODO</i> y/o con variables igualadas a <i>None</i>, salvo (*) en qué momento almacenar las variables que se indican.
# </div>

# %%
class reinforceAgent:
    
    def __init__(self, env, main_network):
        """
        Params
        ======
        env: entorno
        main_network: clase con la red neuronal diseñada
        nblock: bloque de los X últimos episodios de los que se calculará la media de recompensa
        """    
        
        ###################################################
        ######TODO 1: inicializar parámetros ##################
        self.env = env
        self.main_network = main_network
        self.nblock = 100
        
        self.initialize()

        
    ###############################################################
    #####TODO 2: inicializar variables extra que se necesiten######:
    def initialize(self):
        self.batch_rewards = []
        self.batch_actions = []
        self.batch_states = []
        self.batch_counter = 1
        self.training_rewards = []
        self.mean_training_rewards = []
        self.update_loss = []
        
        
    ## TRAINING
    def train(self, gamma=0.99, max_episodes=2000, batch_size=10):
        self.gamma = gamma
        self.batch_size = batch_size
        
        episode = 0
        action_space = np.arange(self.env.action_space.n)
        training = True
        print("Training...")
        while training:
            state0 = env.reset()
            episode_states = [] #array para almacenar estados
            episode_rewards = [] #array para almacenar rewards
            episode_actions = [] #array para almacenar acciones
            gamedone = False
            
            while gamedone == False:
                ###########################################################
                ######TODO 3:  Tomar nueva acción ##############################################
                action_probs = self.main_network.get_action_prob(state0).detach().numpy()  #distribución de probabilidad de las acciones dado el estado actual
                action = np.random.choice(action_space, p=action_probs)   #acción aleatoria de la distribución de probabilidad
                next_state, reward, gamedone, _ = env.step(action)
                              
                #TODO: Almacenamos experiencias (estados, rewards y acciones) que se van obteniendo en este episodio
                episode_states.append(state0)
                episode_rewards.append(reward)
                episode_actions.append(action)
                state0 = next_state
                
                if gamedone:
                    episode += 1
                    
                    # Calculamos el término del retorno menos la línea de base
                    self.batch_rewards.extend(self.discount_rewards(episode_rewards))
                    self.batch_states.extend(episode_states)
                    self.batch_actions.extend(episode_actions)
                    
                    #####################################################################################
                    ###TODO 5: calcular media de recompensas de los últimos X episodios#####
                    self.training_rewards.append(sum(episode_rewards))
                    mean_rewards = np.mean(self.training_rewards[-self.nblock:])
                    self.mean_training_rewards.append(mean_rewards)
                    
                    #####################################################################################
                    ###TODO 6: Cuando se completa el tamaño del batch: actualizar la red (update), almacenar 
                    #la pérdida del entrenamiento, y resetear las variables del episodio necesarias
                    if self.batch_counter == self.batch_size:
                        self.update(self.batch_states, self.batch_rewards, self.batch_actions)
                        self.update_loss = []
                    
                        # Reseteamos las variables del epsiodio
                        self.batch_rewards = []
                        self.batch_actions = []
                        self.batch_states = []
                        self.batch_counter = 1
                        
                    self.batch_counter += 1
                    print("\rEpisode {:d} Mean Rewards {:.2f}\t\t".format(
                        episode, mean_rewards), end="")
                    
                    #####################################################################################
                    ###TODO 8:Hacer las comprobaciones necesarias de fin de episodio
                    # Comprobamos que todavía quedan episodios
                    if episode >= max_episodes:
                        training = False
                        print('\nEpisode limit reached.')
                        break
                        
                        
    ########################################################
    ###TODO 4: cálculo del retorno menos la línea de base###                  
    def discount_rewards(self, rewards):
        discount_r = np.zeros_like(rewards)
        timesteps = range(len(rewards))
        reward_sum = 0
        for i in reversed(timesteps):  #revertimos la dirección del vector para hacer la suma cumulativa
            reward_sum = rewards[i] + self.gamma*reward_sum
            discount_r[i] = reward_sum
        baseline = np.mean(discount_r) # establecemos la media de la recompensa como línea de base
        return discount_r - baseline
        

    #################################################
    ###TODO 7: Cálculo de la pérdida#################
    # Recordatorio: cada actualización es proporcional al producto del retorno y el gradiente de la probabilidad
    # de tomar la acción tomada, dividido por la probabilidad de tomar esa acción (logaritmo natural)
    def calculate_loss(self, state_t, action_t, reward_t):
        logprob = torch.log(self.main_network.get_action_prob(state_t))
        selected_logprobs = reward_t * \
                        logprob[np.arange(len(action_t)), action_t]
        loss = -selected_logprobs.mean()
        return loss
        
    ## Actualización                
    def update(self, batch_s, batch_r, batch_a):
        self.main_network.optimizer.zero_grad()  # eliminamos cualquier gradiente pasado
        state_t = torch.FloatTensor(batch_s)
        reward_t = torch.FloatTensor(batch_r)       
        action_t = torch.LongTensor(batch_a)             
        loss = self.calculate_loss(state_t, action_t, reward_t) # calculamos la pérdida
        loss.backward() # hacemos la diferencia para obtener los gradientes
        self.main_network.optimizer.step() # aplicamos los gradientes a la red neuronal
        # Guardamos los valores de pérdida
        self.update_loss.append(loss.detach().numpy())

# %% [markdown]
# ### Entrenamiento

# %% [markdown]
# A continuación entrenaremos el modelo con los siguientes hiperparámetros:
#    <ul>
#         <li>Velocidad de aprendizaje: 0.01</li>
#         <li>Tamaño del batch: 8</li>
#         <li>Gamma: 0.99</li>
#         <li>Número máximo de episodios: 5000</li>
# </ul>

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.25 ptos):</strong> Definir los hiperparámetros, cargar el modelo de red neuronal y entrenar el agente
# </div>

# %%
# Definimos los parámetros
lr = 0.01  
BATCH_SIZE = 8
GAMMA = 0.99
MAX_EPISODES = 5000

# %%
# Cargamos el modelo
nnr = NeuralNetReinforce(
    env, 
    learning_rate=lr
)

# Creamos el agente
agent = reinforceAgent(
    env, 
    main_network=nnr
)

# Entrenamos al agente
agent.train(
    gamma=GAMMA, 
    max_episodes=MAX_EPISODES, 
    batch_size=BATCH_SIZE
)
# Out:
# Training...
# Episode 8 Mean Rewards -200.00
# <ipython-input-32-7cf56db2b772>:129: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ..\torch\csrc\utils\tensor_new.cpp:201.)
#   state_t = torch.FloatTensor(batch_s)
# Episode 5000 Mean Rewards -200.00
# Episode limit reached.

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Análisis (0.25 ptos):</strong> ¿Qué ha ocurrido? ¿El agente es capaz de aprender la tarea? ¿Por qué?
# </div>

# %% [markdown]
# En este caso el agente no ha sido capaz de aprender la tarea, esto lo podemos ver en que la media de recompensas al finalizar 5000 episodios es -200, la cual es la misma que al comenzar la ejecución, por lo tanto no hay una mejora.
#
# Esto sucede porque la recompensa que obtiene el agente solo la consigue cuando llega al objetivo, es decir, cuando el coche alcanza una posición mayor que 0.5. Por lo tanto, el agente no es capaz de saber si esta yendo por un buen camino o no, una forma de solucionar esto es modificando las recompensas que obtiene el agente, de tal forma que le podamos indiciar si va por el camino correcto o no.

# %% [markdown]
# ### 4.1 Modificación de la recompensa

# %% [markdown]
# Como hemos visto, el entorno de MountainCar únicamente proporciona recompensa cuando el agente llega al objetivo. Pero no hay otras indicaciones que permitan al agente saber que está yendo en la buena dirección de aprendizaje, lo que hace el aprendizaje un poco aleatorio y difícil para el agente.
#
# En este apartado vamos a modificar la recompensa del agente REINFORCE creando una función que dé al agente una recompensa según la posición en la que se encuentra. Que aunque no llegue al objetivo final pueda al menos saber que no iba tan mal encaminado.

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.25 ptos):</strong> Definir una función <code>get_reward()</code> en la que, si el agente se encuentra:
# <ul>
# <li>en una posición mayor o igual a 0.5, la recompensa será: +10</li>
# <li>en una posición mayor que -0.4, la recompensa será: $(1+s)^2$ , es decir, proporcional a la posición</li>
# <li>en cualquier otra posición, se le penalizará con una recompensa de: -1 </li>
# </ul>
# </div>

# %%
def get_reward(position):
    reward = -1

    if position >= 0.5:
        reward = 10
    elif position > -0.4 and position < 0.5:
        reward = (1 + position)**2
    
    return reward

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (0.5 ptos):</strong> Modificar la clase <code>reinforceAgent</code> del ejercicio anterior para que el agente reciba las nuevas recompensas. Entrenar el agente con los mismos parámetros que en el ejercicio anterior, y mostrar las gráficas de recompensas y de la posición final del coche en cada episodio.
# </div>

# %%
class reinforceAgent:
    
    def __init__(self, env, main_network):
        """
        Params
        ======
        env: entorno
        main_network: clase con la red neuronal diseñada
        nblock: bloque de los X últimos episodios de los que se calculará la media de recompensa
        """    
        
        ###################################################
        ######TODO 1: inicializar parámetros ##################
        self.env = env
        self.main_network = main_network
        self.nblock = 100
        
        self.initialize()

        
    ###############################################################
    #####TODO 2: inicializar variables extra que se necesiten######:
    def initialize(self):
        self.batch_rewards = []
        self.batch_actions = []
        self.batch_states = []
        self.batch_counter = 1
        self.training_rewards = []
        self.mean_training_rewards = []
        self.update_loss = []
        self.update_position = []
        
        
    ## TRAINING
    def train(self, gamma=0.99, max_episodes=2000, batch_size=10):
        self.gamma = gamma
        self.batch_size = batch_size
        
        episode = 0
        action_space = np.arange(self.env.action_space.n)
        training = True
        print("Training...")
        while training:
            state0 = env.reset()
            episode_states = [] #array para almacenar estados
            episode_rewards = [] #array para almacenar rewards
            episode_actions = [] #array para almacenar acciones
            gamedone = False
            
            while gamedone == False:
                ###########################################################
                ######TODO 3:  Tomar nueva acción ##############################################
                action_probs = self.main_network.get_action_prob(state0).detach().numpy()  #distribución de probabilidad de las acciones dado el estado actual
                action = np.random.choice(action_space, p=action_probs)   #acción aleatoria de la distribución de probabilidad
                next_state, reward, gamedone, _ = env.step(action)
                
                # Obtenemos la recompensa según la posición (invalidando la que proporciona el entorno)
                reward = get_reward(state0[0])
                              
                #TODO: Almacenamos experiencias (estados, rewards y acciones) que se van obteniendo en este episodio
                episode_states.append(state0)
                episode_rewards.append(reward)
                episode_actions.append(action)
                state0 = next_state
                
                if gamedone:
                    episode += 1
                    
                    # Guardamos la posición final del coche en el episodio
                    self.update_position.append(state0[0])
                    
                    # Calculamos el término del retorno menos la línea de base
                    self.batch_rewards.extend(self.discount_rewards(episode_rewards))
                    self.batch_states.extend(episode_states)
                    self.batch_actions.extend(episode_actions)
                    
                    #####################################################################################
                    ###TODO 5: calcular media de recompensas de los últimos X episodios#####
                    self.training_rewards.append(sum(episode_rewards))
                    mean_rewards = np.mean(self.training_rewards[-self.nblock:])
                    self.mean_training_rewards.append(mean_rewards)
                    
                    #####################################################################################
                    ###TODO 6: Cuando se completa el tamaño del batch: actualizar la red (update), almacenar 
                    #la pérdida del entrenamiento, y resetear las variables del episodio necesarias
                    if self.batch_counter == self.batch_size:
                        self.update(self.batch_states, self.batch_rewards, self.batch_actions)
                        self.update_loss = []
                    
                        # Reseteamos las variables del epsiodio
                        self.batch_rewards = []
                        self.batch_actions = []
                        self.batch_states = []
                        self.batch_counter = 1
                        
                    self.batch_counter += 1
                    print("\rEpisode {:d} Mean Rewards {:.2f}\t\t".format(
                        episode, mean_rewards), end="")
                    
                    #####################################################################################
                    ###TODO 8:Hacer las comprobaciones necesarias de fin de episodio
                    # Comprobamos que todavía quedan episodios
                    if episode >= max_episodes:
                        training = False
                        print('\nEpisode limit reached.')
                        break
                        
                        
    ########################################################
    ###TODO 4: cálculo del retorno menos la línea de base###                  
    def discount_rewards(self, rewards):
        discount_r = np.zeros_like(rewards)
        timesteps = range(len(rewards))
        reward_sum = 0
        for i in reversed(timesteps):  #revertimos la dirección del vector para hacer la suma cumulativa
            reward_sum = rewards[i] + self.gamma*reward_sum
            discount_r[i] = reward_sum
        baseline = np.mean(discount_r) # establecemos la media de la recompensa como línea de base
        return discount_r - baseline
        

    #################################################
    ###TODO 7: Cálculo de la pérdida#################
    # Recordatorio: cada actualización es proporcional al producto del retorno y el gradiente de la probabilidad
    # de tomar la acción tomada, dividido por la probabilidad de tomar esa acción (logaritmo natural)
    def calculate_loss(self, state_t, action_t, reward_t):
        logprob = torch.log(self.main_network.get_action_prob(state_t))
        selected_logprobs = reward_t * \
                        logprob[np.arange(len(action_t)), action_t]
        loss = -selected_logprobs.mean()
        return loss
        
    ## Actualización                
    def update(self, batch_s, batch_r, batch_a):
        self.main_network.optimizer.zero_grad()  # eliminamos cualquier gradiente pasado
        state_t = torch.FloatTensor(batch_s)
        reward_t = torch.FloatTensor(batch_r)       
        action_t = torch.LongTensor(batch_a)             
        loss = self.calculate_loss(state_t, action_t, reward_t) # calculamos la pérdida
        loss.backward() # hacemos la diferencia para obtener los gradientes
        self.main_network.optimizer.step() # aplicamos los gradientes a la red neuronal
        # Guardamos los valores de pérdida
        self.update_loss.append(loss.detach().numpy())
        
        
    def plot_rewards(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.training_rewards, label='Rewards')
        plt.plot(self.mean_training_rewards, label='Mean Rewards')
        plt.title("Evolución de las recompensas")
        plt.xlabel('Episode')
        plt.ylabel('Reward')
        plt.legend(loc="upper left")
        plt.show()
        
    def plot_position(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.update_position)
        plt.title("Evolución de la posición final")
        plt.xlabel('Episode')
        plt.ylabel('Position')
        plt.show()

# %%
# Cargamos el modelo
nnr = NeuralNetReinforce(
    env, 
    learning_rate=lr
)

# Creamos el agente
agent = reinforceAgent(
    env, 
    main_network=nnr
)

# Entrenamos al agente
agent.train(
    gamma=GAMMA, 
    max_episodes=MAX_EPISODES, 
    batch_size=BATCH_SIZE
)
# Out:
# Training...
# Episode 5000 Mean Rewards -24.89
# Episode limit reached.

# %%
agent.plot_rewards()
agent.plot_position()

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Análisis (0.2 ptos):</strong> Comentar los resultados obtenidos. ¿Ha conseguido el agente REINFORCE aprender a llegar al objetivo? Indicar qué se podría hacer para mejorar el resultado.
# </div>

# %% [markdown]
# En este caso vemos que sí que ha habido una mejora en el modelo, sí que consigue aprender más de lo que sucedía con el modelo anterior, pero vemos que esta mejora sigue sin ser suficiente ya que no consigue llegar al objetivo en ninguno de los episodios.
#
# Es curioso ver el cómo el agente rápidamente consigue aprender, es decir, a partir del episodio 100 el agente aprende muchísimo, pero mantiene ese nivel de aprendizaje a lo largo de todos los episodios, esto no sería un problema si el nivel alcanzado nos permitiera llegar al objetivo, pero tal y como vemos en la posición obtenida al final de cada episodio, esto no es así.
#
# Para poder mejorar este resultado podríamos penalizar aún más los estados incorrectos, o premiar de mejor forma los estados intermedios. Es verdad que aumentar la variabilidad de la recompensa puede provocar que el agente no aprenda de forma adecuada, es más, podría hasta no aprender absolutamente nada, por lo que habría que hacer diferentes pruebas. Además, se podría jugar con los hiperparámetros del modelo, como la capacidad de aprendizaje o la gamma, el ver cómo influyen ambos en el aprendizaje.

# %% [markdown]
# ## 5. Comparación de modelos (0.5 ptos)

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio:</strong> Mostrar en un mismo gráfico la evolución de la media de recompensas de los modelos DQN y DDQN, junto con el umbral de recompensa. Comentar los resultados.
# </div>

# %%
plt.figure(figsize=(12,8))
plt.plot(agent_dqn.mean_training_rewards, label='Mean Rewards DQN')
plt.plot(agent_ddqn.mean_training_rewards, label='Mean Rewards DDQN')
plt.axhline(agent_dqn.reward_threshold, color='r', label="Reward threshold")
plt.title("Evolución de las recompensas")
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# En la anterior gráfica podemos ve rel cómo evolucionan las recompensas medias tanto del modelo DQN como del modelo DDQN junto con el umbral.
#
# Si refrescamos los dos primeros ejercicios veíamos que el modelo DQN (línea azul) conseguía llegar en menos episodios al umbral, mientras que el modelo DDQN (línea naranja) necesitaba más episodios para poder converger. Que un modelo tarde más o menos no significa que sea mejor o peor, pero en este caso el modelo que necesita menos episodios para alcanzar el umbral, es decir, el modelo DQN se comportaba peor que el modelo DDQN, con ello me refiero a que no conseguía que a la hora de ejecutar el agente de forma aleatoria acciones según el modelo pudiera llegar a la posición objetivo en cada uno de los episodios.
#
# Que el modelo DDQN se comporte algo mejor que el modelo DQN es algo lógico, ya que DDQN a diferencia de DQN no tiende a sobreestimar los valores de Q, en DQN la red objetivo se encarga de ver qué acción es mejor y calcular su Q, mientras que en DDQN la red objetivo solo calcula el valor de Q de la mejor acción según la red principal, con esto se consigue un mejor rendimiento en el modelo.
#
# En resumen, para este problema hemos visto que DDQN se comporta mejor, pero también es verdad que haciendo diferentes ejecuciones de cada modelo están más igualados, aunque DDQN casi siempre es ligeramente superior.

# %% [markdown]
# ## 6. Creación de un entorno en Gym (2 ptos)

# %% [markdown]
# En este ejercicio diseñaremos un entorno sencillo siguiendo el esquema de los entornos de <code>gym</code>, y trataremos de resolverlo.
#
# Los entornos de <code>gym</code> suelen tener la siguiente estructura:
#
# ```
# class FooEnv(gym.Env):
#   metadata = {'render.modes': ['human']}
#
#   def __init__(self):
#     ...
#   def step(self, action):
#     ...
#   def reset(self):
#     ...
#   def render(self, mode='human', close=False):
#     ...
#
#  ```
#
# Para nuestro entorno usaremos todas estas funciones salvo el <code>render</code> (relativo al diseño de la visualización el entorno).

# %% [markdown]
# Primeramente importamos la librerías necesarias:

# %%
from gym import Env
from gym.spaces import Discrete, Box
import numpy as np
import random

# %% [markdown]
# ### 6.1 Entorno

# %% [markdown]
# El entorno que vamos a diseñar consiste en un regulador de temperatura. Imaginemos que queremos tener una ducha inteligente que sea capaz de mantener la temperatura en un intervalo concreto (37-39 grados) durante todo el tiempo de baño que fijemos. Cada acción será subir o bajar la temperatura un grado, o mantener la temperatura actual.
#
# Concretamente queremos que el regulador de temperatura tenga las siguientes características:
#     <ul>
#         <li>La temperatura (i.e. estado) puede oscilar entre los 0 y los 100 grados</li>
#         <li>La temperatura inicial (i.e. estado inicial) será de 38+-3 grados</li>
#         <li>La duración del baño debe ser de 3 minutos (180 segundos)</li>
#         <li>Las acciones posibles seran:
#             <ul>
#                 <li>0 : bajar temperatura un grado</li>
#                 <li>1 : mantener temperatura</li>
#                 <li>2 : subir temperatura un grado</li>
#             </ul></li>
#         <li>La recompensa será de +1 si la temperatura se encuentra entre 37 y 39 grados, de lo contrario será -1</li>
#         <li>El episodio termina cuando el tiempo de baño se agota (se cumplen los 180 segundos)</li>
#     </ul>

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Ejercicio (0.75 ptos):</strong> Diseñar el entorno <code>TempControlEnv</code> con las características indicadas.
# </div>

# %%
class TempControlEnv(Env):
    def __init__(self):
        '''
        Argumentos:
            - espacio de acciones
            - espacio de observaciones (se recomienda usar la función Box)
            - estado inicial
            - duración episodio
        '''
        ###TODO: inicializar variables###
        # Definición del espacio de acciones y acciones
        self.action_space = Discrete(3)
        self.actions = {
            0: -1, # Bajar la temperatura
            1: 0, # Mantener la temperatura
            2: 1 # Subir la temperatura
        }
        # Definición del espacio de observaciones
        self.observation_space = Box(0, 100, shape=(1,), dtype=np.integer)
        # Definición del estado inicial y duración del episodio
        self.reset()
        
        
        
    def step(self, action):
        '''
        Argumentos:
            - temperatura según acción tomada
            - disminución tiempo de baño
        '''
        
        ###TODO: nueva temperatura y còmput de reducción del tiempo de baño###
        action_value = self.actions[action]
        self.state = self.state + action_value
        
        # Comprobamos que el nuevo valor de la temperatura sea correcto
        if self.state < 0: self.state = 0
        if self.state > 100: self.state = 100
            
        self.time -= 1 # Reducimos en una unidad el tiempo de baño

        
        ###TODO: Cálculo de las recompensas###
        reward = -1
        if self.state >= 37 and self.state <= 39: reward = 1
        
        
        ###TODO: Comprobar si el tiempo de baño se ha agotado###
        done = False
        if self.time == 0: done = True

        
        
        # Aplicamos ruido a la temperatura (exe: alguien abre el agua caliente de otro grifo
        # y altera la temperatura del agua de nuestra ducha)
        self.state += random.randint(-1,1)  # Apply some temperature noise 
        
        info = {} # Set placeholder for info
        
        # Return step information
        return self.state, reward, done, info

    
    
    def reset(self):  
        '''
        Argumentos:
            - resetear temperatura inicial
            - resetear tiempo de baño
        '''
        
        ###TODO: resetear variables###
        self.state = np.random.randint(35, 42) # 38º+-3 -> [35, 42)
        self.time = 180
    
        return self.state

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Ejercicio (0.25 ptos):</strong> Cargar el entorno <code>TempControlEnv</code> y mostrar el espacio de acciones y el espacio de observaciones. Ejecutar 10 episodios con acciones aleatorias, mostrando el episodio y la recompensa obtenida.
# </div>

# %%
# Cargamos el entorno
env = TempControlEnv()

# Mostramos el espacio de acciones y de observaciones
print("El espacio de acciones es: {}".format(env.action_space))
print("El espacio de observaciones es: {}".format(env.observation_space))
# Out:
# El espacio de acciones es: Discrete(3)
# El espacio de observaciones es: Box([0], [100], (1,), int32)

# %%
def translate_action_water(action):
    acciones = {
        0: "Bajar temperatura",
        1: "Mantener temperatura",
        2: "Subir temperatura"
    }
    return acciones[action]

# Ejecutamos 10 episodios
num_episodios = 10
rewards = []

for episodio in range(num_episodios):
    obs = env.reset()
    done = False
    reward_episode = 0
    
    print("***********")
    print("Episodio: " + str(episodio + 1))
    print("***********")
    
    while not done:
        linea = ""
        # Añaidmos el tiempo
        linea += "Tiempo: " + str(env.time)
        # Añadimos la observación
        linea += " " + str(obs)
        # Añadimos la acción
        accion = env.action_space.sample()
        linea += "º " + translate_action_water(accion)
        
        new_obs, reward, done, info = env.step(accion)
        # Añadimos la recompensa
        linea += " \t-> " + str(reward)
        obs = new_obs
        reward_episode += reward
        print(linea)
        if done:
            rewards.append(reward_episode)
            print("Tiempo: 0 " + str(obs) + "º ------------------------------>")
            break
    
print("\n\n")

for episodio in range(num_episodios):
    linea = "Episode: " + str(episodio + 1) + " -> " + str(rewards[episodio])
    print(linea)
# Out:
# ***********
# Episodio: 1
# ***********
# Tiempo: 180 37º Bajar temperatura 	-> -1
# Tiempo: 179 35º Subir temperatura 	-> -1
# Tiempo: 178 36º Mantener temperatura 	-> -1
# Tiempo: 177 35º Mantener temperatura 	-> -1
# Tiempo: 176 34º Bajar temperatura 	-> -1
# Tiempo: 175 33º Bajar temperatura 	-> -1
# Tiempo: 174 31º Bajar temperatura 	-> -1
# Tiempo: 173 29º Subir temperatura 	-> -1
# Tiempo: 172 30º Subir temperatura 	-> -1
# Tiempo: 171 31º Mantener temperatura 	-> -1
# Tiempo: 170 32º Mantener temperatura 	-> -1
# Tiempo: 169 32º Bajar temperatura 	-> -1
# Tiempo: 168 30º Mantener temperatura 	-> -1
# Tiempo: 167 29º Mantener temperatura 	-> -1
# Tiempo: 166 28º Bajar temperatura 	-> -1
# Tiempo: 165 28º Mantener temperatura 	-> -1
# Tiempo: 164 27º Bajar temperatura 	-> -1
# Tiempo: 163 26º Subir temperatura 	-> -1
# Tiempo: 162 28º Subir temperatura 	-> -1
# Tiempo: 161 28º Bajar temperatura 	-> -1
# Tiempo: 160 27º Bajar temperatura 	-> -1
# Tiempo: 159 25º Subir temperatura 	-> -1
# Tiempo: 158 26º Mantener temperatura 	-> -1
# Tiempo: 157 26º Mantener temperatura 	-> -1
# Tiempo: 107 40º Mantener temperatura 	-> -1
# Tiempo: 106 39º Subir temperatura 	-> -1
# Tiempo: 105 41º Mantener temperatura 	-> -1
# Tiempo: 104 40º Mantener temperatura 	-> -1
# Tiempo: 103 41º Subir temperatura 	-> -1
# Tiempo: 102 43º Subir temperatura 	-> -1
# Tiempo: 101 44º Bajar temperatura 	-> -1
# Tiempo: 100 42º Mantener temperatura 	-> -1
# Tiempo: 99 42º Bajar temperatura 	-> -1
# Tiempo: 98 40º Subir temperatura 	-> -1
# Tiempo: 97 41º Subir temperatura 	-> -1
# Tiempo: 96 43º Subir temperatura 	-> -1
# Tiempo: 95 45º Subir temperatura 	-> -1
# Tiempo: 94 45º Mantener temperatura 	-> -1
# Tiempo: 93 44º Bajar temperatura 	-> -1
# Tiempo: 92 44º Bajar temperatura 	-> -1
# Tiempo: 91 42º Subir temperatura 	-> -1
# Tiempo: 90 44º Bajar temperatura 	-> -1
# Tiempo: 89 44º Bajar temperatura 	-> -1
# Tiempo: 88 43º Bajar temperatura 	-> -1
# Tiempo: 87 41º Bajar temperatura 	-> -1
# Tiempo: 86 39º Mantener temperatura 	-> 1
# Tiempo: 85 40º Subir temperatura 	-> -1
# Tiempo: 84 42º Subir temperatura 	-> -1
# Tiempo: 83 43º Bajar temperatura 	-> -1
# Tiempo: 82 43º Bajar temperatura 	-> -1
# Tiempo: 81 42º Subir temperatura 	-> -1
# Tiempo: 80 43º Bajar temperatura 	-> -1
# Tiempo: 79 42º Subir temperatura 	-> -1
# Tiempo: 78 44º Bajar temperatura 	-> -1
# Tiempo: 77 44º Mantener temperatura 	-> -1
# Tiempo: 76 44º Subir temperatura 	-> -1
# Tiempo: 75 44º Subir temperatura 	-> -1
# Tiempo: 74 44º Bajar temperatura 	-> -1
# Tiempo: 73 43º Mantener temperatura 	-> -1
# Tiempo: 72 43º Mantener temperatura 	-> -1
# Tiempo: 71 43º Mantener temperatura 	-> -1
# Tiempo: 70 42º Subir temperatura 	-> -1
# Tiempo: 69 43º Subir temperatura 	-> -1
# Tiempo: 68 45º Mantener temperatura 	-> -1
# Tiempo: 67 45º Mantener temperatura 	-> -1
# Tiempo: 66 46º Mantener temperatura 	-> -1
# Tiempo: 65 45º Subir temperatura 	-> -1
# Tiempo: 64 47º Bajar temperatura 	-> -1
# Tiempo: 63 47º Bajar temperatura 	-> -1
# Tiempo: 62 45º Mantener temperatura 	-> -1
# Tiempo: 61 44º Mantener temperatura 	-> -1
# Tiempo: 60 45º Subir temperatura 	-> -1
# Tiempo: 59 47º Subir temperatura 	-> -1
# Tiempo: 58 47º Subir temperatura 	-> -1
# Tiempo: 57 49º Mantener temperatura 	-> -1
# Tiempo: 56 49º Subir temperatura 	-> -1
# Tiempo: 55 49º Subir temperatura 	-> -1
# Tiempo: 54 49º Mantener temperatura 	-> -1
# Tiempo: 53 50º Subir temperatura 	-> -1
# Tiempo: 52 50º Bajar temperatura 	-> -1
# Tiempo: 51 49º Subir temperatura 	-> -1
# Tiempo: 50 50º Subir temperatura 	-> -1
# Tiempo: 49 50º Mantener temperatura 	-> -1
# Tiempo: 48 51º Mantener temperatura 	-> -1
# Tiempo: 47 52º Bajar temperatura 	-> -1
# Tiempo: 46 51º Subir temperatura 	-> -1
# Tiempo: 45 53º Bajar temperatura 	-> -1
# Tiempo: 44 51º Subir temperatura 	-> -1
# Tiempo: 43 53º Mantener temperatura 	-> -1
# Tiempo: 42 54º Subir temperatura 	-> -1
# Tiempo: 41 56º Bajar temperatura 	-> -1
# Tiempo: 40 54º Bajar temperatura 	-> -1
# Tiempo: 39 53º Bajar temperatura 	-> -1
# Tiempo: 38 52º Bajar temperatura 	-> -1
# Tiempo: 37 52º Bajar temperatura 	-> -1
# Tiempo: 36 52º Mantener temperatura 	-> -1
# Tiempo: 35 51º Mantener temperatura 	-> -1
# Tiempo: 34 50º Mantener temperatura 	-> -1
# Tiempo: 33 51º Subir temperatura 	-> -1
# Tiempo: 32 53º Mantener temperatura 	-> -1
# Tiempo: 31 53º Bajar temperatura 	-> -1
# Tiempo: 30 51º Subir temperatura 	-> -1
# Tiempo: 29 53º Subir temperatura 	-> -1
# Tiempo: 28 53º Mantener temperatura 	-> -1
# Tiempo: 27 54º Mantener temperatura 	-> -1
# Tiempo: 26 55º Bajar temperatura 	-> -1
# Tiempo: 25 55º Mantener temperatura 	-> -1
# Tiempo: 24 55º Subir temperatura 	-> -1
# Tiempo: 23 56º Mantener temperatura 	-> -1
# Tiempo: 22 55º Mantener temperatura 	-> -1
# Tiempo: 21 55º Subir temperatura 	-> -1
# Tiempo: 20 55º Mantener temperatura 	-> -1
# Tiempo: 19 55º Subir temperatura 	-> -1
# Tiempo: 18 57º Mantener temperatura 	-> -1
# Tiempo: 17 58º Subir temperatura 	-> -1
# Tiempo: 16 60º Subir temperatura 	-> -1
# Tiempo: 15 61º Bajar temperatura 	-> -1
# Tiempo: 14 61º Bajar temperatura 	-> -1
# Tiempo: 13 61º Mantener temperatura 	-> -1
# Tiempo: 12 61º Bajar temperatura 	-> -1
# Tiempo: 11 61º Subir temperatura 	-> -1
# Tiempo: 10 61º Subir temperatura 	-> -1
# Tiempo: 9 62º Mantener temperatura 	-> -1
# Tiempo: 8 61º Mantener temperatura 	-> -1
# Tiempo: 7 60º Mantener temperatura 	-> -1
# Tiempo: 6 60º Subir temperatura 	-> -1
# Tiempo: 5 61º Bajar temperatura 	-> -1
# Tiempo: 4 59º Subir temperatura 	-> -1
# Tiempo: 3 60º Mantener temperatura 	-> -1
# Tiempo: 2 59º Bajar temperatura 	-> -1
# Tiempo: 1 59º Bajar temperatura 	-> -1
# Tiempo: 0 59º ------------------------------>
# ***********
# Episodio: 3
# ***********
# Tiempo: 180 39º Subir temperatura 	-> -1
# Tiempo: 179 39º Subir temperatura 	-> -1
# Tiempo: 178 40º Subir temperatura 	-> -1
# Tiempo: 177 41º Subir temperatura 	-> -1
# Tiempo: 176 41º Subir temperatura 	-> -1
# Tiempo: 175 41º Mantener temperatura 	-> -1
# Tiempo: 174 42º Subir temperatura 	-> -1
# Tiempo: 116 52º Subir temperatura 	-> -1
# Tiempo: 115 53º Bajar temperatura 	-> -1
# Tiempo: 114 53º Subir temperatura 	-> -1
# Tiempo: 113 53º Mantener temperatura 	-> -1
# Tiempo: 112 54º Subir temperatura 	-> -1
# Tiempo: 111 56º Bajar temperatura 	-> -1
# Tiempo: 110 54º Subir temperatura 	-> -1
# Tiempo: 109 54º Mantener temperatura 	-> -1
# Tiempo: 108 53º Subir temperatura 	-> -1
# Tiempo: 107 53º Bajar temperatura 	-> -1
# Tiempo: 106 52º Mantener temperatura 	-> -1
# Tiempo: 105 53º Mantener temperatura 	-> -1
# Tiempo: 104 52º Subir temperatura 	-> -1
# Tiempo: 103 54º Bajar temperatura 	-> -1
# Tiempo: 102 54º Bajar temperatura 	-> -1
# Tiempo: 101 52º Bajar temperatura 	-> -1
# Tiempo: 100 51º Bajar temperatura 	-> -1
# Tiempo: 99 51º Subir temperatura 	-> -1
# Tiempo: 98 51º Mantener temperatura 	-> -1
# Tiempo: 97 50º Bajar temperatura 	-> -1
# Tiempo: 96 49º Bajar temperatura 	-> -1
# Tiempo: 95 48º Subir temperatura 	-> -1
# Tiempo: 94 49º Mantener temperatura 	-> -1
# Tiempo: 93 50º Subir temperatura 	-> -1
# Tiempo: 92 52º Bajar temperatura 	-> -1
# Tiempo: 91 52º Mantener temperatura 	-> -1
# Tiempo: 90 53º Bajar temperatura 	-> -1
# Tiempo: 89 53º Bajar temperatura 	-> -1
# Tiempo: 88 52º Bajar temperatura 	-> -1
# Tiempo: 87 51º Subir temperatura 	-> -1
# Tiempo: 86 53º Mantener temperatura 	-> -1
# Tiempo: 85 52º Subir temperatura 	-> -1
# Tiempo: 84 52º Subir temperatura 	-> -1
# Tiempo: 83 52º Bajar temperatura 	-> -1
# Tiempo: 82 50º Subir temperatura 	-> -1
# Tiempo: 81 52º Subir temperatura 	-> -1
# Tiempo: 80 53º Bajar temperatura 	-> -1
# Tiempo: 79 51º Mantener temperatura 	-> -1
# Tiempo: 78 51º Bajar temperatura 	-> -1
# Tiempo: 77 50º Mantener temperatura 	-> -1
# Tiempo: 76 51º Bajar temperatura 	-> -1
# Tiempo: 75 50º Subir temperatura 	-> -1
# Tiempo: 74 51º Bajar temperatura 	-> -1
# Tiempo: 73 49º Mantener temperatura 	-> -1
# Tiempo: 72 49º Mantener temperatura 	-> -1
# Tiempo: 71 49º Mantener temperatura 	-> -1
# Tiempo: 70 49º Bajar temperatura 	-> -1
# Tiempo: 69 47º Subir temperatura 	-> -1
# Tiempo: 68 47º Mantener temperatura 	-> -1
# Tiempo: 67 46º Bajar temperatura 	-> -1
# Tiempo: 66 46º Mantener temperatura 	-> -1
# Tiempo: 65 46º Bajar temperatura 	-> -1
# Tiempo: 64 46º Mantener temperatura 	-> -1
# Tiempo: 63 45º Subir temperatura 	-> -1
# Tiempo: 62 46º Subir temperatura 	-> -1
# Tiempo: 61 46º Mantener temperatura 	-> -1
# Tiempo: 60 46º Mantener temperatura 	-> -1
# Tiempo: 59 45º Bajar temperatura 	-> -1
# Tiempo: 85 15º Subir temperatura 	-> -1
# Tiempo: 84 16º Subir temperatura 	-> -1
# Tiempo: 83 17º Bajar temperatura 	-> -1
# Tiempo: 82 15º Mantener temperatura 	-> -1
# Tiempo: 81 14º Subir temperatura 	-> -1
# Tiempo: 80 15º Subir temperatura 	-> -1
# Tiempo: 79 15º Bajar temperatura 	-> -1
# Tiempo: 78 14º Subir temperatura 	-> -1
# Tiempo: 77 14º Mantener temperatura 	-> -1
# Tiempo: 76 15º Bajar temperatura 	-> -1
# Tiempo: 75 14º Bajar temperatura 	-> -1
# Tiempo: 74 12º Bajar temperatura 	-> -1
# Tiempo: 73 12º Subir temperatura 	-> -1
# Tiempo: 72 13º Subir temperatura 	-> -1
# Tiempo: 71 13º Subir temperatura 	-> -1
# Tiempo: 70 14º Mantener temperatura 	-> -1
# Tiempo: 69 13º Mantener temperatura 	-> -1
# Tiempo: 68 12º Bajar temperatura 	-> -1
# Tiempo: 67 11º Bajar temperatura 	-> -1
# Tiempo: 66 10º Bajar temperatura 	-> -1
# Tiempo: 65 10º Bajar temperatura 	-> -1
# Tiempo: 64 9º Mantener temperatura 	-> -1
# Tiempo: 63 9º Mantener temperatura 	-> -1
# Tiempo: 62 9º Subir temperatura 	-> -1
# Tiempo: 61 9º Mantener temperatura 	-> -1
# Tiempo: 60 10º Mantener temperatura 	-> -1
# Tiempo: 59 9º Bajar temperatura 	-> -1
# Tiempo: 58 9º Subir temperatura 	-> -1
# Tiempo: 57 9º Bajar temperatura 	-> -1
# Tiempo: 56 9º Subir temperatura 	-> -1
# Tiempo: 55 10º Mantener temperatura 	-> -1
# Tiempo: 54 11º Mantener temperatura 	-> -1
# Tiempo: 53 10º Subir temperatura 	-> -1
# Tiempo: 52 11º Bajar temperatura 	-> -1
# Tiempo: 51 10º Bajar temperatura 	-> -1
# Tiempo: 50 9º Mantener temperatura 	-> -1
# Tiempo: 49 9º Bajar temperatura 	-> -1
# Tiempo: 48 9º Bajar temperatura 	-> -1
# Tiempo: 47 7º Mantener temperatura 	-> -1
# Tiempo: 46 7º Bajar temperatura 	-> -1
# Tiempo: 45 5º Bajar temperatura 	-> -1
# Tiempo: 44 4º Mantener temperatura 	-> -1
# Tiempo: 43 5º Subir temperatura 	-> -1
# Tiempo: 42 7º Mantener temperatura 	-> -1
# Tiempo: 41 7º Mantener temperatura 	-> -1
# Tiempo: 40 8º Mantener temperatura 	-> -1
# Tiempo: 39 7º Bajar temperatura 	-> -1
# Tiempo: 38 7º Subir temperatura 	-> -1
# Tiempo: 37 7º Mantener temperatura 	-> -1
# Tiempo: 36 6º Bajar temperatura 	-> -1
# Tiempo: 35 5º Subir temperatura 	-> -1
# Tiempo: 34 7º Subir temperatura 	-> -1
# Tiempo: 33 8º Subir temperatura 	-> -1
# Tiempo: 32 9º Subir temperatura 	-> -1
# Tiempo: 31 11º Bajar temperatura 	-> -1
# Tiempo: 30 11º Mantener temperatura 	-> -1
# Tiempo: 29 12º Subir temperatura 	-> -1
# Tiempo: 28 13º Subir temperatura 	-> -1
# Tiempo: 77 41º Mantener temperatura 	-> -1
# Tiempo: 76 42º Bajar temperatura 	-> -1
# Tiempo: 75 40º Subir temperatura 	-> -1
# Tiempo: 74 42º Mantener temperatura 	-> -1
# Tiempo: 73 42º Subir temperatura 	-> -1
# Tiempo: 72 43º Subir temperatura 	-> -1
# Tiempo: 71 44º Mantener temperatura 	-> -1
# Tiempo: 70 44º Mantener temperatura 	-> -1
# Tiempo: 69 45º Bajar temperatura 	-> -1
# Tiempo: 68 44º Subir temperatura 	-> -1
# Tiempo: 67 46º Bajar temperatura 	-> -1
# Tiempo: 66 46º Mantener temperatura 	-> -1
# Tiempo: 65 47º Subir temperatura 	-> -1
# Tiempo: 64 49º Mantener temperatura 	-> -1
# Tiempo: 63 49º Mantener temperatura 	-> -1
# Tiempo: 62 49º Subir temperatura 	-> -1
# Tiempo: 61 49º Subir temperatura 	-> -1
# Tiempo: 60 50º Subir temperatura 	-> -1
# Tiempo: 59 51º Subir temperatura 	-> -1
# Tiempo: 58 51º Subir temperatura 	-> -1
# Tiempo: 57 53º Subir temperatura 	-> -1
# Tiempo: 56 55º Bajar temperatura 	-> -1
# Tiempo: 55 54º Subir temperatura 	-> -1
# Tiempo: 54 55º Bajar temperatura 	-> -1
# Tiempo: 53 53º Mantener temperatura 	-> -1
# Tiempo: 52 52º Subir temperatura 	-> -1
# Tiempo: 51 53º Bajar temperatura 	-> -1
# Tiempo: 50 53º Mantener temperatura 	-> -1
# Tiempo: 49 53º Subir temperatura 	-> -1
# Tiempo: 48 54º Bajar temperatura 	-> -1
# Tiempo: 47 52º Mantener temperatura 	-> -1
# Tiempo: 46 53º Bajar temperatura 	-> -1
# Tiempo: 45 53º Subir temperatura 	-> -1
# Tiempo: 44 53º Bajar temperatura 	-> -1
# Tiempo: 43 51º Mantener temperatura 	-> -1
# Tiempo: 42 50º Subir temperatura 	-> -1
# Tiempo: 41 52º Bajar temperatura 	-> -1
# Tiempo: 40 51º Mantener temperatura 	-> -1
# Tiempo: 39 52º Bajar temperatura 	-> -1
# Tiempo: 38 50º Bajar temperatura 	-> -1
# Tiempo: 37 50º Mantener temperatura 	-> -1
# Tiempo: 36 51º Mantener temperatura 	-> -1
# Tiempo: 35 51º Mantener temperatura 	-> -1
# Tiempo: 34 50º Bajar temperatura 	-> -1
# Tiempo: 33 50º Mantener temperatura 	-> -1
# Tiempo: 32 50º Mantener temperatura 	-> -1
# Tiempo: 31 49º Mantener temperatura 	-> -1
# Tiempo: 30 48º Bajar temperatura 	-> -1
# Tiempo: 29 48º Bajar temperatura 	-> -1
# Tiempo: 28 48º Mantener temperatura 	-> -1
# Tiempo: 27 48º Subir temperatura 	-> -1
# Tiempo: 26 50º Bajar temperatura 	-> -1
# Tiempo: 25 50º Bajar temperatura 	-> -1
# Tiempo: 24 48º Mantener temperatura 	-> -1
# Tiempo: 23 47º Subir temperatura 	-> -1
# Tiempo: 22 47º Mantener temperatura 	-> -1
# Tiempo: 21 46º Subir temperatura 	-> -1
# Tiempo: 20 48º Mantener temperatura 	-> -1
# Tiempo: 19 49º Mantener temperatura 	-> -1
# Tiempo: 18 49º Subir temperatura 	-> -1
# Tiempo: 17 49º Subir temperatura 	-> -1
# Tiempo: 16 51º Mantener temperatura 	-> -1
# Tiempo: 15 50º Subir temperatura 	-> -1
# Tiempo: 14 52º Subir temperatura 	-> -1
# Tiempo: 13 53º Subir temperatura 	-> -1
# Tiempo: 12 53º Mantener temperatura 	-> -1
# Tiempo: 11 54º Bajar temperatura 	-> -1
# Tiempo: 10 52º Mantener temperatura 	-> -1
# Tiempo: 9 52º Subir temperatura 	-> -1
# Tiempo: 8 52º Subir temperatura 	-> -1
# Tiempo: 7 54º Mantener temperatura 	-> -1
# Tiempo: 6 54º Bajar temperatura 	-> -1
# Tiempo: 5 52º Bajar temperatura 	-> -1
# Tiempo: 4 52º Subir temperatura 	-> -1
# Tiempo: 3 52º Bajar temperatura 	-> -1
# Tiempo: 2 52º Subir temperatura 	-> -1
# Tiempo: 1 54º Subir temperatura 	-> -1
# Tiempo: 0 56º ------------------------------>
#
#
#
# Episode: 1 -> -82
# Episode: 2 -> -146
# Episode: 3 -> -168
# Episode: 4 -> -90
# Episode: 5 -> -106
# Episode: 6 -> -170
# Episode: 7 -> -146
# Episode: 8 -> -122
# Episode: 9 -> -178
# Episode: 10 -> -134

# %% [markdown]
# ### 6.2 Agente regulador de la temperatura

# %% [markdown]
# <div style="background-color: #grey; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Ejercicio (1 pto):</strong> Implementar un agente capaz de regular la temperatura y mantenerla en los intervalos establecidos por el entorno <code>TempControlEnv</code> diseñado. Se puede implementar cualquier tipo de agente visto en el curso (módulos 9, 10 y 11) con los hiperparámetros que se considere conveniente.
#     <ul>
#         <li>Mostrar gráficamente la evolución de las recompensas</li>
#         <li>Mostrar gráficamente la evolución de la temperatura final de cada episodio a lo largo del entrenamiento</li>
#         <li>Testear el modelo de agente con 100 episodios y mostrar las gráficas de recompensas y temperatura</li>
#     </ul>
# </div>

# %%
# Definición de la red neuronal
class NeuralNet(torch.nn.Module):  

    def __init__(self, env, learning_rate=1e-3):
        
        """
        Params
        ======
        n_inputs: tamaño del espacio de estadps
        n_outputs: tamaño del espacio de acciones
        actions: array de acciones posibles
        """
        ######################################
        ##TODO: Inicializar parámetros
        super(NeuralNet, self).__init__()
        self.n_inputs = env.observation_space.shape[0]
        self.n_outputs = env.action_space.n
        self.actions = np.arange(env.action_space.n)
        self.learning_rate = learning_rate
        
        #######################################
        ##TODO: Neural network
        self.model = torch.nn.Sequential(
            torch.nn.Linear(self.n_inputs, 512, bias=True),
            torch.nn.ReLU(),
            torch.nn.Linear(512, 256, bias=True),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 128, bias=True),
            torch.nn.ReLU(),
            torch.nn.Linear(128, self.n_outputs, bias=True),
        )
        
        #######################################
        ##TODO: Initialize optimizer
        self.optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate)


    ### e-greedy method
    def get_action(self, state, epsilon=0.05):
        if np.random.random() < epsilon:
            action = np.random.choice(self.actions)  # acción random
        else:
            qvals = self.get_qvals(state)  # acción del cálculo de Q para esta acción
            action= torch.max(qvals, dim=-1)[1].item()
        return action
    
    
    def get_qvals(self, state):
        if type(state) is tuple:
            state = np.array([np.ravel(s) for s in state])
        else:
            state = (state,)
        state_t = torch.FloatTensor(state)
        
        return self.model(state_t)

# %%
# Implementación del agente
class DQNAgent:
    
    ######################################
    ##TODO 1: Declarar variables
    def __init__(self, env, main_network, buffer, epsilon=0.1, eps_decay=0.99, batch_size=32):
        
        self.env = env
        self.main_network = main_network
        self.target_network = deepcopy(main_network) 
        self.buffer = buffer
        self.epsilon = epsilon
        self.eps_decay = eps_decay
        self.batch_size = batch_size
        self.nblock = 100 # bloque de los X últimos episodios de los que se calculará la media de recompensas
        self.initialize()
        
    ######################################
    ##TODO 2: Inicializar otras variables necesarias
    def initialize(self):
        self.update_loss = []
        self.training_rewards = []
        self.mean_training_rewards = []
        self.training_temperature = []
        self.step_temperature = []
        self.update_temperature = []
        self.update_epsilon = []
        self.sync_eps = []
        self.total_reward = 0
        self.step_count = 0
        self.state0 = self.env.reset()
    
    ######################################
    ##TODO 3: Tomar paso siguiente
    def take_step(self, eps, mode='train'):
        if mode == 'explore': 
            action = self.env.action_space.sample()  # acción aleatoria en el burn-in
        else:
            action = self.main_network.get_action(self.state0, eps) # acción a partir del valor de Q (elección de la acción con mejor Q)
            self.step_count += 1
            
        #TODO: tomar 'step' i obtener nuevo estado y recompensa. Guardar la experiencia en el buffer
        new_state, reward, done, _ = self.env.step(action)
        self.total_reward += reward
        self.step_temperature.append(self.state0)
        self.buffer.append(self.state0, action, reward, done, new_state)
        self.state0 = new_state
        
        #TODO: resetear entorno 'if done'
        if done:
            self.step_temperature.append(self.state0)
            self.update_temperature.append(self.state0) # Guardamos la temperatura final de cada episodio
            self.state0 = self.env.reset()
        return done

    ## TRAINING
    def train(self, gamma=0.99, max_episodes=50000, 
              batch_size=32,
              dnn_update_frequency=4,
              dnn_sync_frequency=2000):
        
        self.gamma = gamma

        # Rellenamos el buffer con N experiencias aleatorias ()
        print("Filling replay buffer...")
        while self.buffer.burn_in_capacity() < 1:
            self.take_step(self.epsilon, mode='explore')

            
        episode = 0
        training = True
        print("Training...")
        while training:
            self.state0 = self.env.reset()
            self.total_reward = 0
            self.step_temperature = []
            gamedone = False
            while gamedone == False:
                # El agente toma una acción
                gamedone = self.take_step(self.epsilon, mode='train')
                
                #################################################################################
                #####TODO 4:  Actualizar la red principal según la frecuencia establecida #######
                if self.step_count % dnn_update_frequency == 0:
                    self.update()
                    
                ########################################################################################
                ###TODO 6: Sincronizar red principal y red objetivo según la frecuencia establecida#####
                if self.step_count % dnn_sync_frequency == 0:
                    self.target_network.load_state_dict(
                        self.main_network.state_dict()
                    )
                    self.sync_eps.append(episode)
                
                if gamedone:                   
                    episode += 1
                        
                    self.update_loss = []
                                    
                    #######################################################################################
                    ###TODO 7: calcular la media de recompensa de los últimos X episodios, y almacenar
                    self.training_rewards.append(self.total_reward)
                    mean_rewards = np.mean(
                        self.training_rewards[-self.nblock:]
                    )
                    self.mean_training_rewards.append(mean_rewards)

                    self.update_epsilon.append(self.epsilon) # Guardamos la evolución de epsilon
                    
                    # CALCULAR LA MEDIA DE LA TEMPERATURA DE LOS ÚLTIMOS X EPISODIOS
                    self.training_temperature.append(
                        self.update_temperature[-1]
                    )
                    mean_temperature = np.mean(
                        self.training_temperature[-self.nblock:]
                    )
                    
                    print("\rEpisode {:d} Mean Rewards {:.2f} Mean Temperature {:.2f} Epsilon {}\t\t".format(
                        episode, mean_rewards, mean_temperature, self.epsilon), end="")
                    
                    #######################################################################################
                    ### TODO 8: Comprobar que todavía quedan episodios. Parar el aprendizaje si se llega al límite
                    if episode >= max_episodes:
                        training = False
                        print('\nEpisode limit reached')
                        break
                    
                    # Termina el juego si la media de la última temperatura ha llegado al intervalo [37,39]
                    # durante X episodios y se haya llegado a un cierta recompensa
                    if mean_temperature >= 37 and mean_temperature <= 39:
                        if mean_rewards >= -20:
                            training = False
                            print('\nEnvironment solved in {} episodes!'.format(
                                episode))
                            break
                    
                    #################################################################################
                    ######TODO 9: Actualizar epsilon según la velocidad de decaimiento fijada########
                    self.epsilon = max(self.epsilon * self.eps_decay, 0.01)

                    
    #####################################         
    #####TODO 5: cálculo de la pérdida###
    def calculate_loss(self, batch):
        # Separamos las variables de la experiencia y las convertimos a tensores 
        states, actions, rewards, dones, next_states = [i for i in batch] 
        rewards_vals = torch.FloatTensor(rewards)
        actions_vals = torch.LongTensor(np.array(actions)).reshape(-1,1)
        dones_t = torch.ByteTensor(dones)
        
        # Obtenemos los valores de Q de la red principal
        qvals = torch.gather(self.main_network.get_qvals(states), 1, actions_vals)
        # Obtenemos los valores de Q objetivo. El parámetro detach() evita que estos valores actualicen la red objetivo
        qvals_next = torch.max(self.target_network.get_qvals(next_states),
                               dim=-1)[0].detach()
        qvals_next[dones_t] = 0 # 0 en estados terminales
        
        #################################################################################
        ### TODO: Calcular ecuación de Bellman
        expected_qvals = self.gamma * qvals_next + rewards_vals
        
        #################################################################################
        ### TODO: Calcular la pérdida (MSE)
        loss = torch.nn.MSELoss()(qvals, expected_qvals.reshape(-1,1))
        
        return loss

    
    def update(self):
        self.main_network.optimizer.zero_grad()  # eliminamos cualquier gradiente pasado
        batch = self.buffer.sample_batch(batch_size=self.batch_size) # seleccionamos un conjunto del buffer
        loss = self.calculate_loss(batch) # calculamos la pérdida
        loss.backward() # hacemos la diferencia para obtener los gradientes
        self.main_network.optimizer.step() # aplicamos los gradientes a la red neuronal
        # Guardamos los valores de pérdida
        self.update_loss.append(loss.detach().numpy())
        
    
    def plot_rewards(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.training_rewards, label='Rewards')
        plt.plot(self.mean_training_rewards, label='Mean Rewards')
        plt.title("Evolución de las recompensas")
        plt.xlabel('Episode')
        plt.ylabel('Reward')
        plt.legend(loc="upper left")
        plt.show()
        
    def plot_temperature(self):
        plt.figure(figsize=(12,8))
        plt.plot(self.update_temperature)
        plt.title("Evolución de la temperatura final")
        plt.xlabel('Episode')
        plt.ylabel('Temperature')
        plt.show()

# %%
# Definición de los hiperparámetros
lr = 0.001            # Velocidad de aprendizaje
BATCH_SIZE = 32       # Tamaño del batch
MAX_EPISODES = 2000   # Número de episodios
BURN_IN = 1000        # Número de episodios para rellenar el buffer
DNN_UPD = 3           # Frecuencia de actualización de la red neuronal
DNN_SYNC = 1000       # Frecuencia de sincronización con la red objetivo
MEMORY_SIZE = 10000   # Capacidad máxima del buffer
GAMMA = 0.99          # Factor de descuento
EPSILON = 1           # Epsilon
EPSILON_DECAY = 0.99   # Decaimiento de epsilon

# %%
# Carga de la red neuronal
dqn = NeuralNet(env, learning_rate=lr)

# Creación del buffer
buffer = experienceReplayBuffer(
    memory_size=MEMORY_SIZE, 
    burn_in=BURN_IN
)

# Creación del agente
agent_dqn = DQNAgent(
    env=env,
    main_network=dqn,
    buffer=buffer,
    epsilon=EPSILON,
    eps_decay=EPSILON_DECAY,
    batch_size=BATCH_SIZE
)

# Entrenamos el agente
agent_dqn.train(
    gamma=GAMMA, 
    max_episodes=MAX_EPISODES, 
    batch_size=BATCH_SIZE,  
    dnn_update_frequency=DNN_UPD, 
    dnn_sync_frequency=DNN_SYNC
)
# Out:
# Filling replay buffer...
# Training...
# <ipython-input-45-1eaee48bedca>:156: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen\native\TensorAdvancedIndexing.cpp:1273.)
#   qvals_next[dones_t] = 0 # 0 en estados terminales
# Episode 108 Mean Rewards -19.24 Mean Temperature 37.90 Epsilon 0.34116606151404244
# Environment solved in 108 episodes!

# %%
agent_dqn.plot_rewards()
agent_dqn.plot_temperature()

# %% [markdown]
# En la primera gráfica podemos observar el cómo evoluciona las recompensas obtenidas en cada episodio del entrenamiento. En este caso vemos que al principio las recompensas obtenidos son muy malas, lo cual es lógico porque el agente todavía no está entrenado. Sin embargo, a medida que va aumentando el número de episodios, el agente consigue aprender el objetivo del problema (mantener la temperatura entre 37 y 39).
#
# Respecto a la segunda gráfica, observamos el cómo evoluciona la temperatura final alcanzada en cada episodio, vemos que al principio es muy aleatoria la temperatura que se obtiene, esto es normal ya que al comienzo del aprendizaje episilon es muy elevado provocando que las acciones seleccionadas sean más aleatorias que seleccionar la acción que maximice Q para ese par estado-acción, pero a medida que avanzan los episodios el valor de epsilon diminuye, generando así que el aprendizaje converja, permitiendo mantener la temperatura entre 37 y 39 grados.

# %%
tem_episodio = []
rew_episodio = []

for episodio in range(100):
    obs = env.reset()
    tem_paso = []
    rew_paso = 0
    
    tem_paso.append(obs)
    
    while True:
        
        accion = agent_dqn.main_network.get_action(obs) # USO DEL MODELO
        new_obs, reward, done, info = env.step(accion)
        
        obs = new_obs
        tem_paso.append(obs)
        rew_paso += reward
        
        if done:
            break
    tem_episodio.append(tem_paso[-1])
    rew_episodio.append(rew_paso)

plt.figure(figsize=(12,8))
plt.plot(rew_episodio)
plt.title("Evolución de las recompensas")
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.show()

plt.figure(figsize=(12,8))
plt.plot(tem_episodio)
plt.title("Evolución de la temperatura final")
plt.xlabel('Temperature')
plt.ylabel('Position')
plt.show()

# %% [markdown]
# Obteniendo las gráficas anteriores podemos ver que el modelo DQN entranado es muy bueno, ya que consigue mantener mayoritariamente la temperatura entre los intervalos 37 y 39 grados.
#
# Es verdad que hay ciertos episodios (4 episodios) en los que el modelo ajustado no ha sido capaz de mantener la temperatura entre 37 y 39 grados, pero esto solo representa un 4% de los casos, es decir, que en el 96% de las veces que vayamos a tomar un baño, este agente va a ser capaz de mantener la temperatura.
